# %% [markdown]
# # Initialization

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
import duckdb

# %%
duck = duckdb.connect()

# %%
duck.execute("load postgres")

# %%
import os
from dotenv import load_dotenv

# Load environment variables from ../.env
load_dotenv("../.env")

duck.execute(
    f"""
    create or replace secret (
        type postgres,
        host '{os.environ.get('DB_HOST', 'localhost')}',
        port {os.environ.get('DB_PORT', 5432)},
        database '{os.environ.get('DB_NAME', 'postgres')}',
        user '{os.environ.get('DB_USER', 'postgres')}',
        password '{os.environ.get('DB_PASSWORD', 'postgres')}'
        );
    
    attach '' as pg (type postgres);
    """
)

# %%
duck.sql(
    """
    select count(*) from pg.medisoft.table_firmenstruktur

    union all

    select count(*) from pg.zoho.Accounts 
    """
)
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │         2594 │
# │        32389 │
# └──────────────┘

# %%
duck.execute(
    """
    begin transaction;

    create or replace temp table medisoft_firms as
    select * replace (trim(name) as name, trim(kuerzel) as kuerzel) from pg.medisoft.table_firmenstruktur;

    create or replace temp table zoho_accounts as
    select Id, trim(Account_Name) as Account_Name from pg.zoho.Accounts;

    commit;
    """
)

# %% [markdown]
# # Firm name match

# %%
duck.execute("""
CREATE OR REPLACE MACRO clean_account_name(str) AS (
  regexp_replace(
    regexp_replace(
      lower(strip_accents(replace(str, '&#38;', ''))), 
      '\b(llc|inc|ltd|corp|corporation|plc|gmbh)\b', 
      '', 'g'
    ), 
    '[^a-z0-9]', 
    '', 'g'
  )
);

""")

# %%
duck.execute("""
create or replace temp table text_matched as
with medisoft_cleaned as (
  select 
    rec_id,
    clean_account_name(coalesce(name, kuerzel)) as clean_name
  from medisoft_firms
), zoho_cleaned as (
  select
    Id,
    clean_account_name(Account_Name) as clean_name
  from pg.zoho.Accounts
)
  select m.clean_name as mc, z.clean_name as zc, jaro_winkler_similarity(m.clean_name, z.clean_name) as sim, rec_id, Id
  from medisoft_cleaned as m
    inner join zoho_cleaned as z
    on (m.clean_name = z.clean_name or jaro_winkler_similarity(m.clean_name, z.clean_name) > 0.95)
  QUALIFY row_number() OVER (PARTITION BY m.rec_id ORDER BY sim DESC) = 1
order by sim

""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
duck.sql("select * from text_matched")
# Out:
# ┌────────────────────────────────────────────┬──────────────────────────────────────────────┬────────────────────┬──────────────────────────────────────┬────────────────────┐
# │                     mc                     │                      zc                      │        sim         │                rec_id                │         Id         │
# │                  varchar                   │                   varchar                    │       double       │               varchar                │      varchar       │
# ├────────────────────────────────────────────┼──────────────────────────────────────────────┼────────────────────┼──────────────────────────────────────┼────────────────────┤
# │ sbhschrottundbaustoffhandelsgesmbh         │ sbhschrottubaustoffhandelsgesmbh             │ 0.9507352941176471 │ 00_9GE00LWYBY                        │ 386758000032311049 │
# │ teamenergiegmbhcokguelzen                  │ teamenergiegmbhcokg                          │              0.952 │ 00_8S9010BCSD                        │ 386758000011736192 │
# │ teamenergiegmbhcokgberlin                  │ teamenergiegmbhcokg                          │              0.952 │ 00_8S90119UT2                        │ 386758000011736192 │
# │ teamenergiegmbhcokglubeck                  │ teamenergiegmbhcokg                          │              0.952 │ 00_8S90109WDT                        │ 386758000011736192 │
# │ deloittegmbh                               │ bwdeloittegmbh                               │ 0.9523809523809524 │ 00_8ZS00WWHTU                        │ 386758000010041145 │
# │ baltictaucherundbergungsbetriebrostockgmbh │ baltictauchereiundbergungsbetriebrostockgmbh │ 0.9528138528138529 │ 00_91W00K73LW                        │ 386758000010037246 │
# │ heartbeatlabsgmbh                          │ heartbeatlabs                                │ 0.9529411764705882 │ F289953A-43DE-4E91-9310-3C3F5DE11C39 │ 386758000009998728 │
# │ jhholdinggmbhcokg                          │ jhholdinggmbh                                │ 0.9529411764705882 │ 00_8R800QA2PT                        │ 386758000021925153 │
# │ mmvermittlunggmbh                          │ mmvermittlung                                │ 0.9529411764705882 │ 00_9S900PUK9W                        │ 386758000032336183 │
# │ oetkerdigital                              │ oetkerdigitalgmbh                            │ 0.9529411764705882 │ 00_8PC00Q22W1                        │ 386758000011736172 │
# │       ·                                    │       ·                                      │                 ·  │       ·                              │         ·          │
# │       ·                                    │       ·                                      │                 ·  │       ·                              │         ·          │
# │       ·                                    │       ·                                      │                 ·  │       ·                              │         ·          │
# │ fenarogmbhcokg                             │ fenarogmbhcokg                               │                1.0 │ 00_8QN00OIP8I                        │ 386758000011736336 │
# │ test                                       │ test                                         │                1.0 │ 00_9VW00WNE4J                        │ 386758000038990114 │
# │ paracurapflegeundassistenzgmbh             │ paracurapflegeundassistenzgmbh               │                1.0 │ 00_9W400TXH21                        │ 386758000050910537 │
# │ ambulanterpflegedienstmedinordgmbhcokg     │ ambulanterpflegedienstmedinordgmbhcokg       │                1.0 │ 00_9WH00U4MDD                        │ 386758000049066100 │
# │ reemtsmacigarettenfabrikengmbh             │ reemtsmacigarettenfabrikengmbh               │                1.0 │ 00_8PO00WGXTE                        │ 386758000009996207 │
# │ minddochealthgmbh                          │ minddochealthgmbh                            │                1.0 │ 00_8NS00RHF2P                        │ 386758000011736367 │
# │ wapnertransporthandelsgmbh                 │ wapnertransporthandelsgmbh                   │                1.0 │ 00_9YE00U56PH                        │ 386758000053425211 │
# │ derixglasstudiosgmbhcokg                   │ derixglasstudiosgmbhcokg                     │                1.0 │ 00_9Z700Z5KQU                        │ 386758000054216761 │
# │ breezytaxi                                 │ breezytaxi                                   │                1.0 │ 61D0D847-4082-4C7D-9090-3AAA34CA65C7 │ 386758000009962328 │
# │ krombergschubertautomotivegmbhcokg         │ krombergschubertautomotivegmbhcokg           │                1.0 │ 00_9PM00NRL4Z                        │ 386758000041628953 │
# ├────────────────────────────────────────────┴──────────────────────────────────────────────┴────────────────────┴──────────────────────────────────────┴────────────────────┤
# │ 915 rows (20 shown)                                                                                                                                              5 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
duck.execute(
    """
    insert into pg.medisoft.table_firms_zoho (rec_id, id_zoho) (
select rec_id, Id 
from medisoft_firms
left join text_matched
using(rec_id)
)"""
)

# %%
print("Hello, world!")

# %% [markdown]
# # Summurization

# %%
duck.sql(
    """
    summarize select * from zoho_accounts
    """
).show(max_rows=1000)

# %%
duck.sql(
    """
    summarize select * from medisoft_firms
    """
).show(max_rows=1000)

# %% [markdown]
# # Sandbox

# %%
duck.execute("call start_ui();")

# %%
duck.sql("select * from pg.medisoft.table_firms_zoho")

# %%
from postal.parser import parse_address

# %%
med_df = duck.sql(
    """
    select rec_id, name, plz, strasse from medisoft_firms where rec_id not in (select rec_id from pg.medisoft.table_firms_zoho where id_zoho is not null)
    """
).df()

# %%
med_df.shape
# Out:
# (1449, 4)

# %%
med_clean_df = med_df.dropna(ignore_index=True)

# %%
med_clean_df['raw_address'] = med_clean_df['strasse'] + ", " + med_clean_df['plz'] + ", Deutschland"
med_clean_df['parsed_address'] = med_clean_df['raw_address'].dropna().apply(parse_address)
# Out:
# /var/folders/99/6ltr_n_s7fq3lxwcq9fhbpdw0000gq/T/ipykernel_28561/1217687468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   med_clean_df['raw_address'] = med_clean_df['strasse'] + ", " + med_clean_df['plz'] + ", Deutschland"
# /var/folders/99/6ltr_n_s7fq3lxwcq9fhbpdw0000gq/T/ipykernel_28561/1217687468.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   med_clean_df['parsed_address'] = med_clean_df['raw_address'].dropna().apply(parse_address)

# %%
parsed_addresses = med_clean_df['parsed_address']

# %%
parsed_addresses[0]
# Out:
# [('rudolf-breidtscheidstrasse', 'road'),
#  ('185', 'house_number'),
#  ('14482', 'postcode'),
#  ('deutschland', 'country')]

# %%
import pandas as pd
import re
from unidecode import unidecode

# %%
med_clean_df['parsed_address'].apply(lambda x: {k: v for v, k in x}).apply(pd.Series)[['road', 'house_number', 'postcode']]
# Out:
#                             road house_number postcode
# 0     rudolf-breidtscheidstrasse          185    14482
# 1                 karl-marx-str.          255    12057
# 2              frankfurter allee          111    10247
# 3                  schudomarstr.           16    12055
# 4             friedenfelser str.           11    12279
# ...                          ...          ...      ...
# 1297                schiesstraße         8-10    40549
# 1298               bützower str.          103    18236
# 1299                         NaN          NaN    40229
# 1300            funkenburgstraße            1    04105
# 1301         brücklesäckerstraße           14    74248
#
# [1302 rows x 3 columns]

# %%
med_clean_df = pd.concat([
    med_clean_df, 
    med_clean_df['parsed_address'].apply(lambda x: {k: v for v, k in x}).apply(pd.Series)[['road', 'house_number', 'postcode']]
], axis=1)

# %%
med_clean_df['road']
# Out:
# 0       rudolf-breidtscheidstrasse
# 1                   karl-marx-str.
# 2                frankfurter allee
# 3                    schudomarstr.
# 4               friedenfelser str.
#                    ...
# 1297                  schiesstraße
# 1298                 bützower str.
# 1299                           NaN
# 1300              funkenburgstraße
# 1301           brücklesäckerstraße
# Name: road, Length: 1302, dtype: object

# %%
def clean_german_road(text):
    if pd.isna(text) or text == '':
        return None
    text = text.lower().strip()
    text = text.replace('ß', 'ss')
    text = re.sub(r'(str\.|str$|str\s|straße|strasse)', '', text)
    text = unidecode(text)
    text = re.sub(r'[^a-z0-9]', '', text)
    
    return text

# %%
med_clean_df['road_cleaned'] = med_clean_df['road'].apply(clean_german_road)

# %%
med_clean_df['road_cleaned']
# Out:
# 0       rudolfbreidtscheid
# 1                 karlmarx
# 2         frankfurterallee
# 3                schudomar
# 4            friedenfelser
#                ...
# 1297                schies
# 1298              butzower
# 1299                  None
# 1300            funkenburg
# 1301         brucklesacker
# Name: road_cleaned, Length: 1302, dtype: object

# %%
zoho_df = duck.sql(
    """
    select Id, Account_Name, Billing_Code, Billing_Street from pg.zoho.Accounts
    """
).df()

# %%
zoho_df.shape
# Out:
# (32389, 4)

# %%
zoho_df.dropna(ignore_index=True, inplace=True)
zoho_df['raw_address'] = zoho_df['Billing_Street'] + ", " + zoho_df['Billing_Code'] + ", Deutschland"
zoho_df['parsed_address'] = zoho_df['raw_address'].apply(parse_address)
parsed_addresses = zoho_df['parsed_address']

# %%
zoho_df = pd.concat([
    zoho_df, 
    zoho_df['parsed_address'].apply(lambda x: {k: v for v, k in x}).apply(pd.Series)[['road', 'house_number', 'postcode']]
], axis=1)

# %%
zoho_df['road_cleaned'] = zoho_df['road'].apply(clean_german_road)

# %%
med_clean_df
# Out:
#                                     rec_id  \
# 0     838259F9-22F9-4D10-A6B4-1E2A7BD53670
# 1     EA85044E-DDF0-4786-A8AC-565972D9FA4E
# 2     3B4E9938-5AB6-4DA2-951D-59E30962CCB1
# 3     30EA28A1-75A6-4D57-AB3A-5F5C2A37914D
# 4     84A565FF-FAE8-4A07-8D53-63CFCF640135
# ...                                    ...
# 1297                         00_A1O00PMTTP
# 1298                         00_A1Q00Q3MF5
# 1299                         00_A1Q00Q4XCG
# 1300                         00_A1R00J04JU
# 1301                         00_A1V00Q5VR6
#
#                                           name     plz  \
# 0              Hasso Plattner Gesundheitscloud   14482
# 1        MoVe Bildungsakademie GmbH &#38; CoKG   12057
# 2           Lasermed Augenklinik im Ringcenter   10247
# 3     Seniorenheim St Richardt z.H Hr Stöppler   12055
# 4                        Kinder in Marienfelde   12279
# ...                                        ...     ...
# 1297                Arztpraxis Dr. med. Lysson   40549
# 1298                         EGN Baustoffmarkt   18236
# 1299                     Radiologie von Werder   40229
# 1300               Zahnarztpraxis Thomas Wendt  04105
# 1301                      Sunbelt Rentals GmbH   74248
#
#                              strasse  \
# 0     Rudolf-Breidtscheidstrasse 185
# 1                 Karl-Marx-Str. 255
# 2              Frankfurter Allee 111
# 3                   Schudomarstr. 16
# 4              Friedenfelser Str. 11
# ...                              ...
# 1297               Schiesstraße 8-10
# 1298              Bützower Str. 103
# 1299                Gumbertstr.90-92
# 1300              Funkenburgstraße 1
# 1301          Brücklesäckerstraße 14
#
#                                             raw_address  \
# 0     Rudolf-Breidtscheidstrasse 185, 14482, Deutsch...
# 1                Karl-Marx-Str. 255, 12057, Deutschland
# 2             Frankfurter Allee 111, 10247, Deutschland
# 3                  Schudomarstr. 16, 12055, Deutschland
# 4             Friedenfelser Str. 11, 12279, Deutschland
# ...                                                 ...
# 1297              Schiesstraße 8-10, 40549, Deutschland
# 1298             Bützower Str. 103 , 18236, Deutschland
# 1299               Gumbertstr.90-92, 40229, Deutschland
# 1300            Funkenburgstraße 1, 04105 , Deutschland
# 1301        Brücklesäckerstraße 14,  74248, Deutschland
#
#                                          parsed_address  \
# 0     [(rudolf-breidtscheidstrasse, road), (185, hou...
# 1     [(karl-marx-str., road), (255, house_number), ...
# 2     [(frankfurter allee, road), (111, house_number...
# 3     [(schudomarstr., road), (16, house_number), (1...
# 4     [(friedenfelser str., road), (11, house_number...
# ...                                                 ...
# 1297  [(schiesstraße, road), (8-10, house_number), (...
# 1298  [(bützower str., road), (103, house_number), (...
# 1299  [(gumbertstr.90-92, house), (40229, postcode),...
# 1300  [(funkenburgstraße, road), (1, house_number), ...
# 1301  [(brücklesäckerstraße, road), (14, house_numbe...
#
#                             road house_number postcode        road_cleaned
# 0     rudolf-breidtscheidstrasse          185    14482  rudolfbreidtscheid
# 1                 karl-marx-str.          255    12057            karlmarx
# 2              frankfurter allee          111    10247    frankfurterallee
# 3                  schudomarstr.           16    12055           schudomar
# 4             friedenfelser str.           11    12279       friedenfelser
# ...                          ...          ...      ...                 ...
# 1297                schiesstraße         8-10    40549              schies
# 1298               bützower str.          103    18236            butzower
# 1299                         NaN          NaN    40229                None
# 1300            funkenburgstraße            1    04105          funkenburg
# 1301         brücklesäckerstraße           14    74248       brucklesacker
#
# [1302 rows x 10 columns]

# %%
med_clean_df.house_number
# Out:
# 0        185
# 1        255
# 2        111
# 3         16
# 4         11
#         ...
# 1297    8-10
# 1298     103
# 1299     NaN
# 1300       1
# 1301      14
# Name: house_number, Length: 1302, dtype: object

# %%
def split_and_clean_house_number(val):
    if pd.isna(val) or val == '':
        return pd.Series([None, None])
    
    # 1. Split the string if it contains '-' or '/'
    # This creates a list, e.g., "62-64" -> ["62", "64"]
    parts = re.split(r'[-/]', str(val))
    
    # 2. Define a helper to remove all non-numeric characters
    def keep_only_digits(s):
        cleaned = re.sub(r'\D', '', s) # \D matches any non-digit
        return cleaned if cleaned != '' else None

    # 3. Process the parts
    num_1 = keep_only_digits(parts[0])
    num_2 = None
    
    # If there was a separator, process the second part
    if len(parts) > 1:
        num_2 = keep_only_digits(parts[1])
        
    return pd.Series([num_1, num_2])

# Apply the function to create two new columns
med_clean_df[['house_num_1', 'house_num_2']] = med_clean_df['house_number'].apply(split_and_clean_house_number)

# %%
zoho_df[['house_num_1', 'house_num_2']] = zoho_df['house_number'].apply(split_and_clean_house_number)

# %%
duck.sql("select * from med_clean_df where house_num_2 is not null")
# Out:
# ┌───────────────┬──────────────────────────────────────────────────┬─────────┬─────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────┬───────────────────┬──────────┬─────────────────────────────────┬─────────────┬─────────────┐
# │    rec_id     │                       name                       │   plz   │                   strasse                   │                            raw_address                            │                                                  parsed_address                                                   │                road                 │   house_number    │ postcode │          road_cleaned           │ house_num_1 │ house_num_2 │
# │    varchar    │                     varchar                      │ varchar │                   varchar                   │                              varchar                              │                                                    varchar[][]                                                    │               varchar               │      varchar      │ varchar  │             varchar             │   varchar   │   varchar   │
# ├───────────────┼──────────────────────────────────────────────────┼─────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────┼───────────────────┼──────────┼─────────────────────────────────┼─────────────┼─────────────┤
# │ 00_8RE00WJW71 │ Kreis Steinburg Hauptamt                         │ 25524   │ Victoriastraße 16/18                        │ Victoriastraße 16/18, 25524, Deutschland                          │ [[victoriastraße, road], [16/18, house_number], [25524, postcode], [deutschland, country]]                        │ victoriastraße                      │ 16/18             │ 25524    │ victoria                        │ 16          │ 18          │
# │ 00_8R300K62UF │ Medicover Berlin Mitte MVZ                       │ 10117   │ Hausvogteiplatz 3-4                         │ Hausvogteiplatz 3-4, 10117, Deutschland                           │ [[hausvogteiplatz, road], [3-4, house_number], [10117, postcode], [deutschland, country]]                         │ hausvogteiplatz                     │ 3-4               │ 10117    │ hausvogteiplatz                 │ 3           │ 4           │
# │ 00_8QP00L4N7V │ EJF                                              │ 14471   │ Knobelsdorffstraße 6-8                      │ Knobelsdorffstraße 6-8, 14471, Deutschland                        │ [[knobelsdorffstraße, road], [6-8, house_number], [14471, postcode], [deutschland, country]]                      │ knobelsdorffstraße                  │ 6-8               │ 14471    │ knobelsdorff                    │ 6           │ 8           │
# │ 00_8X200KZSSL │ EJF                                              │ 14167   │ Osteweg 59-63                               │ Osteweg 59-63, 14167, Deutschland                                 │ [[osteweg, road], [59-63, house_number], [14167, postcode], [deutschland, country]]                               │ osteweg                             │ 59-63             │ 14167    │ osteweg                         │ 59          │ 63          │
# │ 00_8QN00U77G6 │ Uni Elektro Fachhandel GmbH &#38; Co. KG         │ 65760   │ Ludwig-Erhard-Straße 21-39                  │ Ludwig-Erhard-Straße 21-39, 65760, Deutschland                    │ [[ludwig-erhard-straße, road], [21-39, house_number], [65760, postcode], [deutschland, country]]                  │ ludwig-erhard-straße                │ 21-39             │ 65760    │ ludwigerhard                    │ 21          │ 39          │
# │ 00_8QM00PCNSF │ KCGS Tooling GmbH Tochtergesellschaft            │ 51674   │ Bielsteiner Str. 124-130                    │ Bielsteiner Str. 124-130, 51674, Deutschland                      │ [[bielsteiner str., road], [124-130, house_number], [51674, postcode], [deutschland, country]]                    │ bielsteiner str.                    │ 124-130           │ 51674    │ bielsteiner                     │ 124         │ 130         │
# │ 00_8QM00OPSZD │ Finanzamt Köln-Altstadt  z. Hd Stein             │ 50676   │ Am Weidenbach 2-4                           │ Am Weidenbach 2-4, 50676, Deutschland                             │ [[am weidenbach, road], [2-4, house_number], [50676, postcode], [deutschland, country]]                           │ am weidenbach                       │ 2-4               │ 50676    │ amweidenbach                    │ 2           │ 4           │
# │ 00_8Q800UJL9G │ Kock+Voeste                                      │ 12681   │ Wolfener Str. 32-34                         │ Wolfener Str. 32-34, 12681, Deutschland                           │ [[wolfener str., road], [32-34, house_number], [12681, postcode], [deutschland, country]]                         │ wolfener str.                       │ 32-34             │ 12681    │ wolfener                        │ 32          │ 34          │
# │ 00_8PN00L262A │ Synevo                                           │  04-158 │  Zamieniecka 80/401                         │  Zamieniecka 80/401,  04-158, Deutschland                         │ [[zamieniecka, road], [80/401, house_number], [04-158, postcode], [deutschland, country]]                         │ zamieniecka                         │ 80/401            │ 04-158   │ zamieniecka                     │ 80          │ 401         │
# │ 00_8PU00N26TK │ Kita Sonnenland                                  │ 14471   │ Knobelsdorffstr. 6-8                        │ Knobelsdorffstr. 6-8, 14471, Deutschland                          │ [[knobelsdorffstr., road], [6-8, house_number], [14471, postcode], [deutschland, country]]                        │ knobelsdorffstr.                    │ 6-8               │ 14471    │ knobelsdorff                    │ 6           │ 8           │
# │       ·       │        ·                                         │   ·     │          ·                                  │                    ·                                              │                                             ·                                                                     │        ·                            │  ·                │   ·      │      ·                          │ ·           │ ·           │
# │       ·       │        ·                                         │   ·     │          ·                                  │                    ·                                              │                                             ·                                                                     │        ·                            │  ·                │   ·      │      ·                          │ ·           │ ·           │
# │       ·       │        ·                                         │   ·     │          ·                                  │                    ·                                              │                                             ·                                                                     │        ·                            │  ·                │   ·      │      ·                          │ ·           │ ·           │
# │ 00_9XV00KQKE9 │ AP: Daniela Schmidt                              │ 65760   │ Ludwig-Erhard-Straße 21-39                  │ Ludwig-Erhard-Straße 21-39, 65760, Deutschland                    │ [[ludwig-erhard-straße, road], [21-39, house_number], [65760, postcode], [deutschland, country]]                  │ ludwig-erhard-straße                │ 21-39             │ 65760    │ ludwigerhard                    │ 21          │ 39          │
# │ 00_9YA00L197L │ Ocean Scientific International Ltd               │ PO9 1QN │ C7/C8 Endeavour Business Park, Penner Road, │ C7/C8 Endeavour Business Park, Penner Road,, PO9 1QN, Deutschland │ [[c7/c8, house_number], [endeavour business park penner road, road], [po9 1qn, postcode], [deutschland, country]] │ endeavour business park penner road │ c7/c8             │ po9 1qn  │ endeavourbusinessparkpennerroad │ 7           │ 8           │
# │ 00_9YD00KD9QA │ Asbex GmbH - Asbest                              │ 60528   │ Rennbahnstraße 72-74                        │ Rennbahnstraße 72-74, 60528, Deutschland                          │ [[rennbahnstraße, road], [72-74, house_number], [60528, postcode], [deutschland, country]]                        │ rennbahnstraße                      │ 72-74             │ 60528    │ rennbahn                        │ 72          │ 74          │
# │ 00_9YF00NR2DC │ UNI ELEKTRO Eschborn                             │ 65760   │ Ludwig-Erhard-Straße 21-39                  │ Ludwig-Erhard-Straße 21-39, 65760, Deutschland                    │ [[ludwig-erhard-straße, road], [21-39, house_number], [65760, postcode], [deutschland, country]]                  │ ludwig-erhard-straße                │ 21-39             │ 65760    │ ludwigerhard                    │ 21          │ 39          │
# │ 00_9Z600N8PGJ │ Stanzwerke Lehmann                               │ 51063   │ Regentenstr. 36-38                          │ Regentenstr. 36-38, 51063, Deutschland                            │ [[regentenstr., road], [36-38, house_number], [51063, postcode], [deutschland, country]]                          │ regentenstr.                        │ 36-38             │ 51063    │ regenten                        │ 36          │ 38          │
# │ 00_9ZS00OW65Z │ AllClouds GmbH                                   │ 10178   │ Neue Schönhauser Straße 3-5                 │ Neue Schönhauser Straße 3-5  , 10178, Deutschland                 │ [[neue schönhauser straße, road], [3-5, house_number], [10178, postcode], [deutschland, country]]                 │ neue schönhauser straße             │ 3-5               │ 10178    │ neueschonhauser                 │ 3           │ 5           │
# │ 00_A0R00IWRBE │ Internistisch-Kardiologisches Zentrum            │ 10117   │ Friedrichstr. 71 / Quartier 206             │ Friedrichstr. 71 / Quartier 206, 10117, Deutschland               │ [[friedrichstr., road], [71 / quartier 206, house_number], [10117, postcode], [deutschland, country]]             │ friedrichstr.                       │ 71 / quartier 206 │ 10117    │ friedrich                       │ 71          │ 206         │
# │ 00_A0S00N3G6U │ TROX HGI GmbH                                    │ 48477   │ Gutenbergstraße 8-14,                       │ Gutenbergstraße 8-14,, 48477, Deutschland                         │ [[gutenbergstraße, road], [8-14, house_number], [48477, postcode], [deutschland, country]]                        │ gutenbergstraße                     │ 8-14              │ 48477    │ gutenberg                       │ 8           │ 14          │
# │ 00_A1D00NR8ME │ team energie GmbH &#38; Co. KG Itzehoe Gasstraße │ 25524   │ Gasstraße 30-34                             │ Gasstraße 30-34, 25524, Deutschland                               │ [[gasstraße, road], [30-34, house_number], [25524, postcode], [deutschland, country]]                             │ gasstraße                           │ 30-34             │ 25524    │ gas                             │ 30          │ 34          │
# │ 00_A1O00PMTTP │ Arztpraxis Dr. med. Lysson                       │ 40549   │ Schiesstraße 8-10                           │ Schiesstraße 8-10, 40549, Deutschland                             │ [[schiesstraße, road], [8-10, house_number], [40549, postcode], [deutschland, country]]                           │ schiesstraße                        │ 8-10              │ 40549    │ schies                          │ 8           │ 10          │
# ├───────────────┴──────────────────────────────────────────────────┴─────────┴─────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────┴───────────────────┴──────────┴─────────────────────────────────┴─────────────┴─────────────┤
# │ 128 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                      12 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
duck.sql("select * from pg.medisoft.table_firmenstruktur where rec_id = '406E85E9-3D74-41D6-8346-651CA08A3150'")
# Out:
# ┌──────────────────────────────────────┬──────────────────────────────────────┬──────────────────────────────────────────┬───────────────────────────────────────────────────┬─────────┬────────────────┬───────────────┬───────────────┬─────────────────┬───────────────┬───────────────┬───────────────┬────────────────┬──────────────────────────────────────────┬────────────┬─────────────────┬─────────┬─────────┬───────────┬────────────┬─────────────────┬──────────────────────────┬─────────┬─────────┬─────────┬───────────────┬─────────┬───────────────┬─────────┬──────────────────┬─────────┬────────────────────────┬─────────┬──────────┬─────────┬───────────────────┬────────────┬─────────────────────────┬────────────┬─────────────┬─────────────┬────────────────────┐
# │                rec_id                │               kuerzel                │                   name                   │                       pfad                        │ passiv  │ abrechnung_art │ laptop_update │ laptop_delete │ historiepflicht │ statistik_kz1 │ statistik_kz2 │ statistik_kz3 │ sync_timestamp │                sync_hash                 │ sequenz_nr │ farbe_verwenden │ status  │  ebene  │ has_child │ has_child2 │ inoriskrelevant │         strasse          │   plz   │   ort   │ mandant │   vater_id    │  staat  │    telefon    │  name2  │ betreuender_arzt │   fax   │         email          │ ebene2  │ telefon2 │  name3  │ betreuender_arzt2 │ email_sifa │ email_personalabteilung │ betrieb_nr │ rng_vorlage │ betriebsart │ rechnungsanschrift │
# │               varchar                │               varchar                │                 varchar                  │                      varchar                      │ varchar │    varchar     │    varchar    │    varchar    │     varchar     │    varchar    │    varchar    │    varchar    │    varchar     │                 varchar                  │  varchar   │     varchar     │ varchar │ varchar │  varchar  │  varchar   │     varchar     │         varchar          │ varchar │ varchar │ varchar │    varchar    │ varchar │    varchar    │ varchar │     varchar      │ varchar │        varchar         │ varchar │ varchar  │ varchar │      varchar      │  varchar   │         varchar         │  varchar   │   varchar   │   varchar   │      varchar       │
# ├──────────────────────────────────────┼──────────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────────────┼─────────┼────────────────┼───────────────┼───────────────┼─────────────────┼───────────────┼───────────────┼───────────────┼────────────────┼──────────────────────────────────────────┼────────────┼─────────────────┼─────────┼─────────┼───────────┼────────────┼─────────────────┼──────────────────────────┼─────────┼─────────┼─────────┼───────────────┼─────────┼───────────────┼─────────┼──────────────────┼─────────┼────────────────────────┼─────────┼──────────┼─────────┼───────────────────┼────────────┼─────────────────────────┼────────────┼─────────────┼─────────────┼────────────────────┤
# │ 406E85E9-3D74-41D6-8346-651CA08A3150 │ HitFox Group GmbH, Hendrik Krawinkel │ Herr Hendrik Krawinkel HitFox Group GmbH │ BSH Berlin / HitFox Group GmbH, Hendrik Krawinkel │ 0       │ 0              │ 0             │ 0             │ 0               │ 0             │ 0             │ 0             │ 20250901103105 │ de1244edec560b93eaaaf05008df83de418e8020 │ 500001068  │ 0               │ Aktiv   │ 2       │ 0         │ 0          │ 0               │ Rosa-Luxemburg-Strasse 2 │ 10178   │ Berlin  │ Berlin  │ 00_8JB00PDT8X │ DE      │ 030 577025820 │ NULL    │ NULL             │ NULL    │ berlin@hitfoxgroup.com │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# └──────────────────────────────────────┴──────────────────────────────────────┴──────────────────────────────────────────┴───────────────────────────────────────────────────┴─────────┴────────────────┴───────────────┴───────────────┴─────────────────┴───────────────┴───────────────┴───────────────┴────────────────┴──────────────────────────────────────────┴────────────┴─────────────────┴─────────┴─────────┴───────────┴────────────┴─────────────────┴──────────────────────────┴─────────┴─────────┴─────────┴───────────────┴─────────┴───────────────┴─────────┴──────────────────┴─────────┴────────────────────────┴─────────┴──────────┴─────────┴───────────────────┴────────────┴─────────────────────────┴────────────┴─────────────┴─────────────┴────────────────────┘

# %%
med_clean_df[med_clean_df['rec_id'] == '406E85E9-3D74-41D6-8346-651CA08A3150']
# Out:
#                                  rec_id  \
# 5  406E85E9-3D74-41D6-8346-651CA08A3150
#
#                                        name    plz                   strasse  \
# 5  Herr Hendrik Krawinkel HitFox Group GmbH  10178  Rosa-Luxemburg-Strasse 2
#
#                                     raw_address  \
# 5  Rosa-Luxemburg-Strasse 2, 10178, Deutschland
#
#                                       parsed_address                    road  \
# 5  [(rosa-luxemburg-strasse, road), (2, house_num...  rosa-luxemburg-strasse
#
#   house_number postcode   road_cleaned house_num_1 house_num_2
# 5            2    10178  rosaluxemburg           2        None

# %%
duck.sql("select clean_account_name(name) from med_clean_df where rec_id = '406E85E9-3D74-41D6-8346-651CA08A3150'")
# Out:
# ┌─────────────────────────────────────┐
# │     clean_account_name("name")      │
# │               varchar               │
# ├─────────────────────────────────────┤
# │ herrhendrikkrawinkelhitfoxgroupgmbh │
# └─────────────────────────────────────┘

# %%
zoho_df[zoho_df['Id'] == '386758000009959846']
# Out:
#                     Id Account_Name Billing_Code           Billing_Street  \
# 31  386758000009959846       Hitfox        10178  Rosa-Luxemburg-Straße 2
#
#                                     raw_address  \
# 31  Rosa-Luxemburg-Straße 2, 10178, Deutschland
#
#                                        parsed_address                   road  \
# 31  [(rosa-luxemburg-straße, road), (2, house_numb...  rosa-luxemburg-straße
#
#    house_number postcode   road_cleaned house_num_1 house_num_2
# 31            2    10178  rosaluxemburg           2        None

# %%
duck.sql("select clean_account_name(Account_Name) from zoho_df where Id = '386758000009959846'")
# Out:
# ┌──────────────────────────────────┐
# │ clean_account_name(Account_Name) │
# │             varchar              │
# ├──────────────────────────────────┤
# │ hitfox                           │
# └──────────────────────────────────┘

# %%
zoho_df.road_cleaned
# Out:
# 0          billingaddress
# 1             schonholzer
# 2                    None
# 3          karlliebknecht
# 4        landsbergerallee
#                ...
# 25946              4stock
# 25947              marien
# 25948          gotzkowsky
# 25949                 ost
# 25950            holzdamm
# Name: road_cleaned, Length: 25951, dtype: object

# %%
address_match_df = duck.sql("""
select 
    name,
    Account_Name,
    jaro_winkler_similarity(clean_account_name(name), clean_account_name(Account_Name)) as similarity, 
    med_clean_df.* exclude (name),
    zoho_df.* exclude (Account_Name),
from med_clean_df
join zoho_df
on med_clean_df.road_cleaned = zoho_df.road_cleaned
and med_clean_df.plz = zoho_df.postcode
and (med_clean_df.house_number = zoho_df.house_number
    or med_clean_df.house_num_1 = zoho_df.house_num_1
    or med_clean_df.house_num_2 = zoho_df.house_num_2)
where (similarity > 0.7 or (clean_account_name(name) in clean_account_name(Account_Name) or clean_account_name(Account_Name) in clean_account_name(name)))
QUALIFY row_number() OVER (
    PARTITION BY med_clean_df.rec_id  -- On groupe par ligne Medisoft
    ORDER BY similarity DESC          -- On trie par la meilleure similarité
) = 1
order by similarity desc
""").df()

# %%
address_match_df
# Out:
#                                         name  \
# 0                                       ESMT
# 1           Notübernachtung für Wohnungslose
# 2                                        EJF
# 3                                        EJF
# 4                    Tagespflege Tegeler See
# 5                        Janusz Korczak Haus
# 6                        Dr. Dieter Grüttner
# 7                            MKM-Ihr Friseur
# 8                               Einsteinkids
# 9                  Junges Ensemble Stuttgart
# 10                   Zahnärzte am Hammerpark
# 11                                    Pflege
# 12                           Kita Pusteblume
# 13              Kindergarten Aufgepasst e.V.
# 14  Herr Hendrik Krawinkel HitFox Group GmbH
# 15                                 Roth GmbH
# 16                                 Roth GmbH
# 17                                      KJHV
# 18                            KJHV Eva Laube
#
#                                          Account_Name  similarity  \
# 0   ESMT European School of Management and Technol...    0.695035
# 1   EJF gemeinnützige GmbH Notübernachtung für Woh...    0.694636
# 2        EJF gemeinnützige AG - Kindergarten Waldhaus    0.692982
# 3   EJF gemeinnützige AG - Integrations-Kindertage...    0.684211
# 4   EJF Diakonie-Pflege gGmbH - Tagespflege Tegele...    0.665990
# 5   EJF gemeinnützige AG - Dr. Janusz Korczak-Haus...    0.649979
# 6   Gemeinschaftspraxis Dr. Dieter Grüttner, Dr. B...    0.622475
# 7               Maria Kristin Müller MKM- Ihr Friseur    0.612452
# 8    EJF gemeinnützige AG - Kinderclub "Einsteinkids"    0.594444
# 9   Verein Kinder- und Jugendkultur / Junges Ensem...    0.584573
# 10  Dr. Kai Oliver Hagenlocher - Zahnärzte am Hamm...    0.565499
# 11                Diakonie-Pflege Reinickendorf gGmbH    0.562500
# 12         EJF - gemeinnützige AG - Kita "Pusteblume"    0.493221
# 13                                    AUFGEPASST e.V.    0.482143
# 14                                             Hitfox    0.463492
# 15                 DIE ARBEITSSCHUTZBERATER Roth GmbH    0.459677
# 16                 DIE ARBEITSSCHUTZBERATER Roth GmbH    0.459677
# 17            EJF gemeinnützige AG - KJHV "Eva Laube"    0.427778
# 18            EJF gemeinnützige AG - KJHV "Eva Laube"    0.394444
#
#                                   rec_id    plz                   strasse  \
# 0                          00_98500R7OO2  10178             Schloßplatz 1
# 1                          00_8R400J6MEK  13503         Am Bärensprung 52
# 2                          00_8QP00MB160  14469        Amundsenstraße 24a
# 3                          00_8QP00L4N7V  14471    Knobelsdorffstraße 6-8
# 4                          60_8MZ00SBF74  13507         Eisenhammerweg 10
# 5                          00_8KE00RENQD  10319        Erich-Kurz-Str. 4a
# 6                          00_8TQ00JOXQF  42799           Am Wallgraben 1
# 7                          00_9X800SR1JU  51143           Schmittgasse 62
# 8                          00_8UC00LLIXE  14471        Knobelsdorffstr. 7
# 9                          00_9JI00U03OU  70173          Eberhardstr. 61a
# 10                         00_9PV00KK9KU  20535  Carl- Petersen- Str. 101
# 11                         00_8QV00LF84G  13507         Eisenhammerweg 12
# 12                         00_8LV00R7IF0  10317            Wönnichstr. 74
# 13                         00_8N500J8UYC  10713         Paretzer Straße 2
# 14  406E85E9-3D74-41D6-8346-651CA08A3150  10178  Rosa-Luxemburg-Strasse 2
# 15                         00_9W500PESFW  64589             Marktstraße 6
# 16                         00_9PP00JI3DL  64589             Marktstraße 6
# 17                         00_8MT00LFIAA  14482     stubenrauchstr. 12-14
# 18                         00_8MY00JSO9Q  14482     Stubenrauchstr. 12-14
#
#                                      raw_address  \
# 0              Schloßplatz 1, 10178, Deutschland
# 1          Am Bärensprung 52, 13503, Deutschland
# 2         Amundsenstraße 24a, 14469, Deutschland
# 3     Knobelsdorffstraße 6-8, 14471, Deutschland
# 4          Eisenhammerweg 10, 13507, Deutschland
# 5         Erich-Kurz-Str. 4a, 10319, Deutschland
# 6            Am Wallgraben 1, 42799, Deutschland
# 7            Schmittgasse 62, 51143, Deutschland
# 8         Knobelsdorffstr. 7, 14471, Deutschland
# 9           Eberhardstr. 61a, 70173, Deutschland
# 10  Carl- Petersen- Str. 101, 20535, Deutschland
# 11         Eisenhammerweg 12, 13507, Deutschland
# 12            Wönnichstr. 74, 10317, Deutschland
# 13         Paretzer Straße 2, 10713, Deutschland
# 14  Rosa-Luxemburg-Strasse 2, 10178, Deutschland
# 15             Marktstraße 6, 64589, Deutschland
# 16             Marktstraße 6, 64589, Deutschland
# 17     stubenrauchstr. 12-14, 14482, Deutschland
# 18     Stubenrauchstr. 12-14, 14482, Deutschland
#
#                                        parsed_address                    road  \
# 0   [[schloßplatz, road], [1, house_number], [1017...             schloßplatz
# 1   [[am bärensprung, road], [52, house_number], [...          am bärensprung
# 2   [[amundsenstraße, road], [24a, house_number], ...          amundsenstraße
# 3   [[knobelsdorffstraße, road], [6-8, house_numbe...      knobelsdorffstraße
# 4   [[eisenhammerweg, road], [10, house_number], [...          eisenhammerweg
# 5   [[erich-kurz-str., road], [4a, house_number], ...         erich-kurz-str.
# 6   [[am wallgraben, road], [1, house_number], [42...           am wallgraben
# 7   [[schmittgasse, road], [62, house_number], [51...            schmittgasse
# 8   [[knobelsdorffstr., road], [7, house_number], ...        knobelsdorffstr.
# 9   [[eberhardstr., road], [61a, house_number], [7...            eberhardstr.
# 10  [[carl petersen str., road], [101, house_numbe...      carl petersen str.
# 11  [[eisenhammerweg, road], [12, house_number], [...          eisenhammerweg
# 12  [[wönnichstr., road], [74, house_number], [103...             wönnichstr.
# 13  [[paretzer straße, road], [2, house_number], [...         paretzer straße
# 14  [[rosa-luxemburg-strasse, road], [2, house_num...  rosa-luxemburg-strasse
# 15  [[marktstraße, road], [6, house_number], [6458...             marktstraße
# 16  [[marktstraße, road], [6, house_number], [6458...             marktstraße
# 17  [[stubenrauchstr., road], [12-14, house_number...         stubenrauchstr.
# 18  [[stubenrauchstr., road], [12-14, house_number...         stubenrauchstr.
#
#    house_number  ... Billing_Code           Billing_Street  \
# 0             1  ...        10178            Schloßplatz 1
# 1            52  ...        13503        Am Bärensprung 52
# 2           24a  ...        14469        Amundsenstr. 24 a
# 3           6-8  ...        14471      Knobelsdorffstr 6-8
# 4            10  ...        13507        Eisenhammerweg 10
# 5            4a  ...        10319     Erich-Kurz-Straße 4a
# 6             1  ...        42799          Am Wallgraben 1
# 7            62  ...        51143          Schmittgasse 62
# 8             7  ...        14471     Knobelsdorffstraße 7
# 9           61a  ...        70173       Eberhardstraße 61a
# 10          101  ...        20535   Carl-Petersen-Str. 101
# 11           12  ...        13507        Eisenhammerweg 12
# 12           74  ...        10317           Wönnichstr. 74
# 13            2  ...        10713        Paretzer Straße 2
# 14            2  ...        10178  Rosa-Luxemburg-Straße 2
# 15            6  ...        64589            Marktstraße 6
# 16            6  ...        64589            Marktstraße 6
# 17        12-14  ...        14482    Stubenrauchstr. 12/14
# 18        12-14  ...        14482    Stubenrauchstr. 12/14
#
#                                   raw_address_1  \
# 0             Schloßplatz 1, 10178, Deutschland
# 1         Am Bärensprung 52, 13503, Deutschland
# 2         Amundsenstr. 24 a, 14469, Deutschland
# 3       Knobelsdorffstr 6-8, 14471, Deutschland
# 4         Eisenhammerweg 10, 13507, Deutschland
# 5      Erich-Kurz-Straße 4a, 10319, Deutschland
# 6           Am Wallgraben 1, 42799, Deutschland
# 7           Schmittgasse 62, 51143, Deutschland
# 8      Knobelsdorffstraße 7, 14471, Deutschland
# 9        Eberhardstraße 61a, 70173, Deutschland
# 10   Carl-Petersen-Str. 101, 20535, Deutschland
# 11        Eisenhammerweg 12, 13507, Deutschland
# 12           Wönnichstr. 74, 10317, Deutschland
# 13        Paretzer Straße 2, 10713, Deutschland
# 14  Rosa-Luxemburg-Straße 2, 10178, Deutschland
# 15            Marktstraße 6, 64589, Deutschland
# 16            Marktstraße 6, 64589, Deutschland
# 17    Stubenrauchstr. 12/14, 14482, Deutschland
# 18    Stubenrauchstr. 12/14, 14482, Deutschland
#
#                                      parsed_address_1                 road_1  \
# 0   [[schloßplatz, road], [1, house_number], [1017...            schloßplatz
# 1   [[am bärensprung, road], [52, house_number], [...         am bärensprung
# 2   [[amundsenstr., road], [24 a, house_number], [...           amundsenstr.
# 3   [[knobelsdorffstr, road], [6-8, house_number],...        knobelsdorffstr
# 4   [[eisenhammerweg, road], [10, house_number], [...         eisenhammerweg
# 5   [[erich-kurz-straße, road], [4a, house_number]...      erich-kurz-straße
# 6   [[am wallgraben, road], [1, house_number], [42...          am wallgraben
# 7   [[schmittgasse, road], [62, house_number], [51...           schmittgasse
# 8   [[knobelsdorffstraße, road], [7, house_number]...     knobelsdorffstraße
# 9   [[eberhardstraße, road], [61a, house_number], ...         eberhardstraße
# 10  [[carl-petersen-str., road], [101, house_numbe...     carl-petersen-str.
# 11  [[eisenhammerweg, road], [12, house_number], [...         eisenhammerweg
# 12  [[wönnichstr., road], [74, house_number], [103...            wönnichstr.
# 13  [[paretzer straße, road], [2, house_number], [...        paretzer straße
# 14  [[rosa-luxemburg-straße, road], [2, house_numb...  rosa-luxemburg-straße
# 15  [[marktstraße, road], [6, house_number], [6458...            marktstraße
# 16  [[marktstraße, road], [6, house_number], [6458...            marktstraße
# 17  [[stubenrauchstr., road], [12/14, house_number...        stubenrauchstr.
# 18  [[stubenrauchstr., road], [12/14, house_number...        stubenrauchstr.
#
#    house_number_1 postcode_1  road_cleaned_1 house_num_1_1 house_num_2_1
# 0               1      10178    schlossplatz             1          None
# 1              52      13503   ambarensprung            52          None
# 2            24 a      14469        amundsen            24          None
# 3             6-8      14471    knobelsdorff             6             8
# 4              10      13507  eisenhammerweg            10          None
# 5              4a      10319       erichkurz             4          None
# 6               1      42799    amwallgraben             1          None
# 7              62      51143    schmittgasse            62          None
# 8               7      14471    knobelsdorff             7          None
# 9             61a      70173        eberhard            61          None
# 10            101      20535    carlpetersen           101          None
# 11             12      13507  eisenhammerweg            12          None
# 12             74      10317         wonnich            74          None
# 13              2      10713        paretzer             2          None
# 14              2      10178   rosaluxemburg             2          None
# 15              6      64589           markt             6          None
# 16              6      64589           markt             6          None
# 17          12/14      14482     stubenrauch            12            14
# 18          12/14      14482     stubenrauch            12            14
#
# [19 rows x 25 columns]

# %%
address_match_df[['Account_Name', 'name', 'similarity']]
# Out:
#                                          Account_Name  \
# 0   ESMT European School of Management and Technol...
# 1   EJF gemeinnützige GmbH Notübernachtung für Woh...
# 2        EJF gemeinnützige AG - Kindergarten Waldhaus
# 3   EJF gemeinnützige AG - Integrations-Kindertage...
# 4   EJF Diakonie-Pflege gGmbH - Tagespflege Tegele...
# 5   EJF gemeinnützige AG - Dr. Janusz Korczak-Haus...
# 6   Gemeinschaftspraxis Dr. Dieter Grüttner, Dr. B...
# 7               Maria Kristin Müller MKM- Ihr Friseur
# 8    EJF gemeinnützige AG - Kinderclub "Einsteinkids"
# 9   Verein Kinder- und Jugendkultur / Junges Ensem...
# 10  Dr. Kai Oliver Hagenlocher - Zahnärzte am Hamm...
# 11                Diakonie-Pflege Reinickendorf gGmbH
# 12         EJF - gemeinnützige AG - Kita "Pusteblume"
# 13                                    AUFGEPASST e.V.
# 14                                             Hitfox
# 15                 DIE ARBEITSSCHUTZBERATER Roth GmbH
# 16                 DIE ARBEITSSCHUTZBERATER Roth GmbH
# 17            EJF gemeinnützige AG - KJHV "Eva Laube"
# 18            EJF gemeinnützige AG - KJHV "Eva Laube"
#
#                                         name  similarity
# 0                                       ESMT    0.695035
# 1           Notübernachtung für Wohnungslose    0.694636
# 2                                        EJF    0.692982
# 3                                        EJF    0.684211
# 4                    Tagespflege Tegeler See    0.665990
# 5                        Janusz Korczak Haus    0.649979
# 6                        Dr. Dieter Grüttner    0.622475
# 7                            MKM-Ihr Friseur    0.612452
# 8                               Einsteinkids    0.594444
# 9                  Junges Ensemble Stuttgart    0.584573
# 10                   Zahnärzte am Hammerpark    0.565499
# 11                                    Pflege    0.562500
# 12                           Kita Pusteblume    0.493221
# 13              Kindergarten Aufgepasst e.V.    0.482143
# 14  Herr Hendrik Krawinkel HitFox Group GmbH    0.463492
# 15                                 Roth GmbH    0.459677
# 16                                 Roth GmbH    0.459677
# 17                                      KJHV    0.427778
# 18                            KJHV Eva Laube    0.394444

# %%
duck.sql(
    """
    update pg.medisoft.table_firms_zoho
    set id_zoho = address_match_df.Id
    from address_match_df
    where pg.medisoft.table_firms_zoho.rec_id = address_match_df.rec_id
    """)

# %%
duck.sql("select * from address_match_df")

# %%
duck.sql("""
select * 
from pg.medisoft.table_firms_zoho   
where id_zoho is null
and rec_id in (select rec_id from address_match_df)
""")
# Out:
# ┌───────┬──────────────────────────────────────┬─────────┐
# │  id   │                rec_id                │ id_zoho │
# │ int32 │               varchar                │ varchar │
# ├───────┼──────────────────────────────────────┼─────────┤
# │ 11136 │ 406E85E9-3D74-41D6-8346-651CA08A3150 │ NULL    │
# │ 11170 │ 00_8R400J6MEK                        │ NULL    │
# │ 11178 │ 00_8QV00LF84G                        │ NULL    │
# │ 11185 │ 00_8QP00MB160                        │ NULL    │
# │ 11186 │ 00_8QP00L4N7V                        │ NULL    │
# │ 11259 │ 00_8N500J8UYC                        │ NULL    │
# │ 11262 │ 60_8MZ00SBF74                        │ NULL    │
# │ 11265 │ 00_8MY00JSO9Q                        │ NULL    │
# │ 11266 │ 00_8MT00LFIAA                        │ NULL    │
# │ 11273 │ 00_8LV00R7IF0                        │ NULL    │
# │ 11306 │ 00_8KE00RENQD                        │ NULL    │
# │ 11379 │ 00_8TQ00JOXQF                        │ NULL    │
# │ 11386 │ 00_8UC00LLIXE                        │ NULL    │
# │ 11782 │ 00_98500R7OO2                        │ NULL    │
# │ 12131 │ 00_9JI00U03OU                        │ NULL    │
# │ 12351 │ 00_9PP00JI3DL                        │ NULL    │
# │ 12362 │ 00_9PV00KK9KU                        │ NULL    │
# │ 12757 │ 00_9W500PESFW                        │ NULL    │
# │ 12796 │ 00_9X800SR1JU                        │ NULL    │
# ├───────┴──────────────────────────────────────┴─────────┤
# │ 19 rows                                      3 columns │
# └────────────────────────────────────────────────────────┘

# %%
duck.sql("select * from medisoft_firms where rec_id not in (select rec_id from pg.medisoft.table_firms_zoho where id_zoho is not null)")
# Out:
# ┌──────────────────────────────────────┬────────────────────────────────────────────────────┬────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────┬─────────┬────────────────┬───────────────┬───────────────┬─────────────────┬───────────────┬───────────────┬───────────────┬────────────────┬──────────────────────────────────────────┬────────────┬─────────────────┬──────────┬─────────┬───────────┬────────────┬─────────────────┬────────────────────────────────┬─────────┬───────────────────────┬────────────┬───────────────┬─────────┬───────────────┬─────────────────┬──────────────────┬──────────────┬────────────────────────────┬─────────┬──────────┬─────────┬───────────────────┬────────────┬─────────────────────────┬────────────┬─────────────┬─────────────┬────────────────────┐
# │                rec_id                │                      kuerzel                       │                        name                        │                                pfad                                │ passiv  │ abrechnung_art │ laptop_update │ laptop_delete │ historiepflicht │ statistik_kz1 │ statistik_kz2 │ statistik_kz3 │ sync_timestamp │                sync_hash                 │ sequenz_nr │ farbe_verwenden │  status  │  ebene  │ has_child │ has_child2 │ inoriskrelevant │            strasse             │   plz   │          ort          │  mandant   │   vater_id    │  staat  │    telefon    │      name2      │ betreuender_arzt │     fax      │           email            │ ebene2  │ telefon2 │  name3  │ betreuender_arzt2 │ email_sifa │ email_personalabteilung │ betrieb_nr │ rng_vorlage │ betriebsart │ rechnungsanschrift │
# │               varchar                │                      varchar                       │                      varchar                       │                              varchar                               │ varchar │    varchar     │    varchar    │    varchar    │     varchar     │    varchar    │    varchar    │    varchar    │    varchar     │                 varchar                  │  varchar   │     varchar     │ varchar  │ varchar │  varchar  │  varchar   │     varchar     │            varchar             │ varchar │        varchar        │  varchar   │    varchar    │ varchar │    varchar    │     varchar     │     varchar      │   varchar    │          varchar           │ varchar │ varchar  │ varchar │      varchar      │  varchar   │         varchar         │  varchar   │   varchar   │   varchar   │      varchar       │
# ├──────────────────────────────────────┼────────────────────────────────────────────────────┼────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┼─────────┼────────────────┼───────────────┼───────────────┼─────────────────┼───────────────┼───────────────┼───────────────┼────────────────┼──────────────────────────────────────────┼────────────┼─────────────────┼──────────┼─────────┼───────────┼────────────┼─────────────────┼────────────────────────────────┼─────────┼───────────────────────┼────────────┼───────────────┼─────────┼───────────────┼─────────────────┼──────────────────┼──────────────┼────────────────────────────┼─────────┼──────────┼─────────┼───────────────────┼────────────┼─────────────────────────┼────────────┼─────────────┼─────────────┼────────────────────┤
# │ 00_54Y012ERKE                        │ Musterfirma                                        │ Musterfirma                                        │ Musterfirma                                                        │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20240513143250 │ a67e6e60d18281e9fc9dfb2cd24cae40eba87bfc │ 698        │ 0               │ Aktiv    │ 1       │ 1         │ 0          │ 0               │ NULL                           │ NULL    │ NULL                  │ NULL       │ NULL          │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 838259F9-22F9-4D10-A6B4-1E2A7BD53670 │ Hasso Plattner Gesundheitscloud                    │ Hasso Plattner Gesundheitscloud                    │ BSH Berlin / Hasso Plattner Gesundheitscloud                       │ 0       │ 0              │ 0             │ 0             │ 0               │ 0             │ 0             │ 0             │ 20250901103105 │ 84115857948dc1c097cc828435e1d297fc6b5ee8 │ 500001051  │ 0               │ Neukunde │ 2       │ 0         │ 0          │ 0               │ Rudolf-Breidtscheidstrasse 185 │ 14482   │ Potsdam               │ Berlin     │ 00_8JB00PDT8X │ DE      │ 0331 55091306 │ NULL            │ NULL             │ NULL         │ NULL                       │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 91C53D79-EE09-465B-9B26-38351EAB5F88 │ TSA Ausbildungszentrum                             │ TSA Ausbildungszentrum                             │ BSH Berlin / TSA Ausbildungszentrum                                │ 0       │ 0              │ 0             │ 0             │ 0               │ 0             │ 0             │ 0             │ 20250901103105 │ 71137305a36ac15495a6ec23fffe98ef15a3b990 │ 500001056  │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ NULL                           │ NULL    │ NULL                  │ Berlin     │ 00_8JB00PDT8X │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ EA85044E-DDF0-4786-A8AC-565972D9FA4E │ MoVe Bildungsakademie GmbH &#38; CoKG              │ MoVe Bildungsakademie GmbH &#38; CoKG              │ BSH Berlin / MoVe Bildungsakademie GmbH &#38; CoKG                 │ 0       │ 0              │ 0             │ 0             │ 0               │ 0             │ 0             │ 0             │ 20250901103105 │ 9c0763c4615ae68c89d116810363c4db11b27926 │ 500001062  │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Karl-Marx-Str. 255             │ 12057   │ Berlin                │ Berlin     │ 00_8JB00PDT8X │ NULL    │ 030- 58582157 │ NULL            │ NULL             │ NULL         │ NULL                       │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 3B4E9938-5AB6-4DA2-951D-59E30962CCB1 │ Lasermed Augenklinik im Ringcenter                 │ Lasermed Augenklinik im Ringcenter                 │ BSH Berlin / Lasermed Augenklinik im Ringcenter                    │ 0       │ 0              │ 0             │ 0             │ 0               │ 0             │ 0             │ 0             │ 20250901103105 │ 42cb5042478cca6cf8b5bb0a0b5b326ee58d5ae9 │ 500001063  │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Frankfurter Allee 111          │ 10247   │ Berlin Friedrichshain │ Berlin     │ 00_8JB00PDT8X │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 30EA28A1-75A6-4D57-AB3A-5F5C2A37914D │ Seniorenheim St Richardt                           │ Seniorenheim St Richardt z.H Hr Stöppler           │ BSH Berlin / Seniorenheim St Richardt                              │ 0       │ 0              │ 0             │ 0             │ 0               │ 0             │ 0             │ 0             │ 20250901103105 │ 8b65ee3262106fa0e06e864a15452dd8857e8212 │ 500001066  │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Schudomarstr. 16               │ 12055   │ Berlin                │ Berlin     │ 00_8JB00PDT8X │ NULL    │ 0303198616711 │ z.H Hr Stöppler │ NULL             │ NULL         │ NULL                       │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 84A565FF-FAE8-4A07-8D53-63CFCF640135 │ Kinder in Marienfelde                              │ Kinder in Marienfelde                              │ BSH Berlin / One World gGmbH / Kinder in Marienfelde               │ 0       │ 0              │ 0             │ 0             │ 0               │ 0             │ 0             │ 0             │ 20250901103105 │ 77b2589d061b743647b93f028286cc68b0ada3ba │ 500001067  │ 0               │ Aktiv    │ 3       │ 0         │ 0          │ 0               │ Friedenfelser Str. 11          │ 12279   │ Berlin                │ Berlin     │ 00_8GX00Y4CYB │ DE      │ 030-71996-00  │ NULL            │ NULL             │ 030-71996-02 │ info@kinder-marienfelde.de │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 406E85E9-3D74-41D6-8346-651CA08A3150 │ HitFox Group GmbH, Hendrik Krawinkel               │ Herr Hendrik Krawinkel HitFox Group GmbH           │ BSH Berlin / HitFox Group GmbH, Hendrik Krawinkel                  │ 0       │ 0              │ 0             │ 0             │ 0               │ 0             │ 0             │ 0             │ 20250901103105 │ de1244edec560b93eaaaf05008df83de418e8020 │ 500001068  │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Rosa-Luxemburg-Strasse 2       │ 10178   │ Berlin                │ Berlin     │ 00_8JB00PDT8X │ DE      │ 030 577025820 │ NULL            │ NULL             │ NULL         │ berlin@hitfoxgroup.com     │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_8YG00LOM02                        │ paint                                              │ NULL                                               │ BSH Berlin / Tesla / paint                                         │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250901103107 │ 2c15617e2a950b802c368a793f1e2f1910b5a9cb │ 1708       │ 0               │ Aktiv    │ 3       │ 0         │ 0          │ 0               │ NULL                           │ NULL    │ NULL                  │ Berlin     │ 00_8YG00LMXRH │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ B2A66FD5-A7B5-423A-B5E3-7CC10D658664 │ MyTaxi                                             │ MyTaxi                                             │ BSH Berlin / MyTaxi                                                │ 0       │ 0              │ 0             │ 0             │ 0               │ 0             │ 0             │ 0             │ 20250901103105 │ 4596fd319e0b88f3fefc2fe185abef26ee3980af │ 500001074  │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ NULL                           │ NULL    │ NULL                  │ Berlin     │ 00_8JB00PDT8X │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ NULL    │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │       ·                              │  ·                                                 │  ·                                                 │  ·                                                                 │ ·       │ ·              │ ·             │ ·             │ ·               │ ·             │ ·             │ ·             │       ·        │                    ·                     │  ·         │ ·               │   ·      │ ·       │ ·         │ ·          │ ·               │  ·                             │  ·      │  ·                    │   ·        │  ·            │  ·      │  ·            │  ·              │  ·               │  ·           │  ·                         │ ·       │  ·       │  ·      │  ·                │  ·         │  ·                      │  ·         │  ·          │  ·          │  ·                 │
# │       ·                              │  ·                                                 │  ·                                                 │  ·                                                                 │ ·       │ ·              │ ·             │ ·             │ ·               │ ·             │ ·             │ ·             │       ·        │                    ·                     │  ·         │ ·               │   ·      │ ·       │ ·         │ ·          │ ·               │  ·                             │  ·      │  ·                    │   ·        │  ·            │  ·      │  ·            │  ·              │  ·               │  ·           │  ·                         │ ·       │  ·       │  ·      │  ·                │  ·         │  ·                      │  ·         │  ·          │  ·          │  ·                 │
# │       ·                              │  ·                                                 │  ·                                                 │  ·                                                                 │ ·       │ ·              │ ·             │ ·             │ ·               │ ·             │ ·             │ ·             │       ·        │                    ·                     │  ·         │ ·               │   ·      │ ·       │ ·         │ ·          │ ·               │  ·                             │  ·      │  ·                    │   ·        │  ·            │  ·      │  ·            │  ·              │  ·               │  ·           │  ·                         │ ·       │  ·       │  ·      │  ·                │  ·         │  ·                      │  ·         │  ·          │  ·          │  ·                 │
# │ 00_A1H00JJM4G                        │ NULL                                               │ NULL                                               │ NULL                                                               │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250820091544 │ f1d1db2ba21c38d656db0779dda11a638fff214d │ 3761       │ 0               │ Aktiv    │ 1       │ 0         │ 0          │ 0               │ NULL                           │ NULL    │ NULL                  │ Berlin     │ NULL          │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_A1I00J05C3                        │ ATLAS MARIDAN  ApS Germany                         │ ATLAS MARIDAN  ApS Germany                         │ BSH Rostock / ATLAS MARIDAN  ApS Germany                           │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250819084603 │ f493f7d76ef2bb23b29d395142a891b25168417c │ 3768       │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Heerenholz 17                  │ 28307   │  Bremen               │ Rostock    │ 00_8OB00MF3F6 │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_A1J00I9AM5                        │ EJF Ambulante Wohnhilfen                           │ EJF Ambulante Wohnhilfen                           │ BSH Berlin / EJF Ambulante Wohnhilfen                              │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250901103109 │ d4871c35452056ea65a25871eeab359fb10b09b7 │ 3770       │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Heinrich-Mann-Str. 29          │ 13156   │ Berlin                │ Berlin     │ 00_8JB00PDT8X │ NULL    │ 01717437689   │ Frank Gips      │ NULL             │ NULL         │ invoiceEJFjAG@ejf.de       │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_A1K00HW67Q                        │ Bootsbau Kock                                      │ Bootsbau Kock                                      │ BSH Rostock / Bootsbau Kock                                        │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250821081551 │ 414a254a01c9da7d470338158c3dd42a4ecb59f2 │ 3773       │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │  Ebereschenallee 12            │ 17213   │ Malchow               │ Rostock    │ 00_8OB00MF3F6 │ NULL    │ 0172 8862281  │ NULL            │ NULL             │ NULL         │ info@bootsbau-kock.de      │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_A1K00ROH9J                        │ Ärzte ohne Grenzen e.V. / Médecins Sans Frontières │ Ärzte ohne Grenzen e.V. / Médecins Sans Frontières │ BSH Rostock / Ärzte ohne Grenzen e.V. / Médecins Sans Frontières   │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250821124524 │ 65e2d946349c9b526298c0894a0563059647dd11 │ 3774       │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Schwedenstr. 9                 │ 13359   │ Berlin                │ Rostock    │ 00_8OB00MF3F6 │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ Invoice@berlin.msf.org     │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_A1O00PMTTP                        │ Arztpraxis Dr. med. Lysson                         │ Arztpraxis Dr. med. Lysson                         │ BSH Düsseldorf / Arztpraxis Dr. med. Lysson                        │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250825114833 │ 9b3a095169303194f4c435ab7c79e7a2ec3456f7 │ 3775       │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Schiesstraße 8-10              │ 40549   │ Düsseldorf            │ düsseldorf │ 00_8QN00M755W │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_A1Q00Q3MF5                        │ EGN Baustoffmarkt                                  │ EGN Baustoffmarkt                                  │ BSH Rostock / EGN Baustoffmarkt                                    │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250827120209 │ 3bd1713a0e5f78f07cd17eb811778591923d1d8d │ 3776       │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │  Bützower Str. 103             │ 18236   │ Kröpelin              │ Rostock    │ 00_8OB00MF3F6 │ NULL    │ 038292 82480  │ NULL            │ NULL             │ NULL         │ NULL                       │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_A1Q00Q4XCG                        │ Radiologie von Werder                              │ Radiologie von Werder                              │ BSH Düsseldorf / Radiologie von Werder                             │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250827120319 │ f67a2334ba458352db2f16c895e242996354fdbd │ 3777       │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Gumbertstr.90-92               │ 40229   │ Düsseldorf            │ Düsseldorf │ 00_8QN00M755W │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_A1R00J04JU                        │ Zahnarztpraxis Thomas Wendt                        │ Zahnarztpraxis Thomas Wendt                        │ BSH Rostock / Zahnarztpraxis Thomas Wendt                          │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250828084644 │ 5f40050a109b23d363f11f15421f723c6d6d07c0 │ 3780       │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │ Funkenburgstraße 1             │ 04105   │ Leipzig               │ Rostock    │ 00_8OB00MF3F6 │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# │ 00_A1V00Q5VR6                        │ Sunbelt Rentals GmbH                               │ Sunbelt Rentals GmbH                               │ BSH Rostock / Sunbelt Rentals GmbH                                 │ 0       │ 0              │ 0             │ 0             │ 1               │ 0             │ 0             │ 0             │ 20250901120345 │ 3cbbf71086222708e50085f0a4cd6fce0b45cf58 │ 3785       │ 0               │ Aktiv    │ 2       │ 0         │ 0          │ 0               │  Brücklesäckerstraße 14        │  74248  │  Ellhofen             │ Rostock    │ 00_8OB00MF3F6 │ NULL    │ NULL          │ NULL            │ NULL             │ NULL         │ NULL                       │ 1       │ NULL     │ NULL    │ NULL              │ NULL       │ NULL                    │ NULL       │ NULL        │ NULL        │ NULL               │
# ├──────────────────────────────────────┴────────────────────────────────────────────────────┴────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────┴─────────┴────────────────┴───────────────┴───────────────┴─────────────────┴───────────────┴───────────────┴───────────────┴────────────────┴──────────────────────────────────────────┴────────────┴─────────────────┴──────────┴─────────┴───────────┴────────────┴─────────────────┴────────────────────────────────┴─────────┴───────────────────────┴────────────┴───────────────┴─────────┴───────────────┴─────────────────┴──────────────────┴──────────────┴────────────────────────────┴─────────┴──────────┴─────────┴───────────────────┴────────────┴─────────────────────────┴────────────┴─────────────┴─────────────┴────────────────────┤
# │ 1449 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                42 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
duck.sql("select * from medisoft_firms where rec_id in (select rec_id from pg.medisoft.table_firms_zoho where id_zoho is null)").show(max_rows=1000)

# %%
from deepparse.parser import AddressParser

# %%
duck.sql("""
create or replace temp table medisoft_zoho_name_exact_match as 
    with name_matches as (
        select m.rec_id, z.Id, m.name, m.kuerzel, z.Account_Name, z.Account_Status, * 
        from medisoft_firms m
        join zoho_accounts z
            on m.name = z.Account_Name
    ),
    kuerzel_matches as (
        select m.rec_id, z.Id, m.name, m.kuerzel, z.Account_Name, z.Account_Status, * 
        from medisoft_firms m
        join zoho_accounts z
            on m.kuerzel = z.Account_Name
        where m.rec_id not in (select rec_id from name_matches)
        and z.Id not in (select Id from name_matches)
    )
    select * from name_matches
    union all
    select * from kuerzel_matches
    """
)

# %%
duck.sql("select * from medisoft_zoho_name_exact_match")

# %%
duck.sql("select Website from zoho_accounts where Website is not null and Website like '%tms-viersen.de%'")

# %%
duck.sql("select email from medisoft_firms where email is not null")

# %%
duck.sql(
    """
    create or replace temp table medisoft_firms_clean as (
    select rec_id, TRIM(REGEXP_REPLACE(
            REGEXP_REPLACE(
                REGEXP_REPLACE(replace(LOWER(name), '&#38;', ' and '), '[^\w\s]', '', 'g'), 
                '\b(inc|llc|ltd|corp|corporation|limited|gmbh|co|company|sa|sas)\b', '', 'g'
            ), 
            '\s+', ' ', 'g'
        )) AS clean_name
        , TRIM(REGEXP_REPLACE(
            REGEXP_REPLACE(
                REGEXP_REPLACE(replace(LOWER(kuerzel), '&#38;', ' and '), '[^\w\s]', '', 'g'), 
                '\b(inc|llc|ltd|corp|corporation|limited|gmbh|co|company|sa|sas)\b', '', 'g'
            ), 
            '\s+', ' ', 'g'
        )) AS clean_kuerzel,
        
    from medisoft_firms
    )
    """
)

# %%
duck.sql(
    """
    create or replace temp table zoho_accounts_clean as (
    select Id, TRIM(REGEXP_REPLACE(
            REGEXP_REPLACE(
                REGEXP_REPLACE(replace(LOWER(Account_Name), '&#38;', ' and '), '[^\w\s]', '', 'g'), 
                '\b(inc|llc|ltd|corp|corporation|limited|gmbh|co|company|sa|sas)\b', '', 'g'
            ), 
            '\s+', ' ', 'g'
        )) AS clean_name from zoho_accounts
    )   
    """
)

# %%
duck.sql(
    """
    select * 
    from medisoft_firms_clean m
    join zoho_accounts_clean z
        on m.clean_name = z.clean_name
    """
)
