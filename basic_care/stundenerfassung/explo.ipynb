# %%
import duckdb

# %%
duck = duckdb.connect()

# %%
duck.sql(
    """
    select * from read_csv('/Users/adrienblanquer/Downloads/PADOA EXPORT_Stundenerfassung Dashboard_neu_20260604_V1(Leistungserfassung_neue Liste) (1).csv', skip=6) where Datum is not null
    """
).to_csv('stundenerfassung_all.csv')
