# %% [markdown]
# # Imports

# %%
from postal.parser import parse_address
import json
from duckdb.sqltypes import VARCHAR
import pandas as pd
import re
from unidecode import unidecode
import sys
import os
sys.path.append(os.path.abspath(".."))
sys.path.append(os.path.abspath("../merge_tables"))
from merge_tables.db.connection import connect_to_postgres_via_duckdb
from merge_tables.db.tables import create_clean_account_name_macro

# %% [markdown]
# # duck init

# %%
duck = connect_to_postgres_via_duckdb()
create_clean_account_name_macro(duck)
# Out:
# ✓ Successfully connected DuckDB to PostgreSQL database 'medisoft'
# ✓ Created clean_account_name macro

# %%
def udf_parse_address(address: str) -> str:
    parsed = parse_address(address)
    components = {component: value for value, component in parsed}
    return json.dumps(components)

# %%
def udf_clean_german_road(text):
    """Clean German road names for matching."""
    if pd.isna(text) or text == '':
        return None
    text = text.lower().strip()
    text = text.replace('ß', 'ss')
    text = re.sub(r'(str\.|str$|str\s|straße|strasse)', '', text)
    text = unidecode(text)
    text = re.sub(r'[^a-z0-9]', '', text)
    return text

# %%
duck.create_function("udf_parse_address", udf_parse_address, [VARCHAR], VARCHAR)
duck.create_function("udf_clean_german_road", udf_clean_german_road, [VARCHAR], VARCHAR)

# %% [markdown]
# # name matching

# %% [markdown]
# ## easybill rows

# %%
duck.sql("""
         select distinct on("Kontakt: Kundennummer") * from read_csv('/Users/adrienblanquer/Downloads/easybill_contacts_inv_rec_activ.csv') 
         """)
# Out:
# ┌─────────────────────┬───────────────────────┬────────────────────────────┬────────────────────┬─────────────────┬─────────────────────────────────┬────────────────┬──────────────────┬───────────────┬───────────────────────┬─────────────────────────────────────────────────────────────────┬────────────────────────────┬───────────────────────┬───────────────────┬─────────────────────┬───────────────┬──────────────────────┬───────────────────┬────────────────────────────────┬───────────────────────┬──────────────────────────────┬────────────────────────┬───────────────────────────────┬────────────────────┬────────────────────┬──────────────┬───────────────────────┬──────────────────────────────────────────┬───────────────────────────────────────────┬───────────────────┬─────────────────────────────────────────────────────────────────┬─────────────────┬─────────────────────┬──────────────────────────────┬──────────────────────────┬─────────────────────────┬───────────────────────┬───────────────────┬──────────────────────┬───────────────────────┬──────────────┬────────────────────────┬──────────────────────────────────────┬───────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────────┬──────────────────────────────┬────────────────────────────────┬─────────────────────────────────┬─────────────────────────────────────────────────┬──────────────────────────────────┬───────────────────────────────┬───────────────────────────────────┬───────────────────────────────────┬────────────────────────────────┬────────────────────────────────────────────┬───────────────────────────────────────┬──────────────────────────────┬─────────────────────────────────────┬───────────────────────────────┬──────────────────────────────────────┬──────────────────────┬───────────────────────┬────────────────────────────────────┬─────────────────────────────────────┬──────────────────────────┬─────────────────────┬────────────────────────┬────────────────────────────┬──────────────────────────────┬─────────────────────────────┬────────────────────────────────┬──────────────┬─────────────────────────────┬────────────────────────────────────────┬───────────────────────────────┬──────────────────────────────────────┬─────────────────────┐
# │ Kontakt: Kontakt ID │ Kontakt: Kundennummer │ Kontakt: Lieferantennummer │ Kontakt: Abteilung │ Kontakt: Anrede │ Kontakt: Persönlich/Vertraulich │ Kontakt: Titel │ Kontakt: Vorname │ Kontakt: Name │ Kontakt: Geburtsdatum │                         Kontakt: Firma                          │ Kontakt: Straße/Hausnummer │ Kontakt: Postleitzahl │   Kontakt: Ort    │ Kontakt: Bundesland │ Kontakt: Land │ Kontakt: Land (Code) │ Kontakt: Postfach │ Kontakt: Postfach-Postleitzahl │ Kontakt: Postfach-Ort │ Kontakt: Postfach-Bundesland │ Kontakt: Postfach-Land │ Kontakt: Postfach-Land (Code) │ Kontakt: Telefon 1 │ Kontakt: Telefon 2 │ Kontakt: Fax │ Kontakt: Mobiltelefon │             Kontakt: E-Mail              │         Kontakt: Weitere E-Mails          │ Kontakt: Internet │                         Kontakt: Info 1                         │ Kontakt: Info 2 │ Kontakt: Steuer Nr. │ Kontakt: Umsatzsteuer-ID Nr. │ Kontakt: Registergericht │ Kontakt: Registernummer │ Kontakt: Kontoinhaber │ Kontakt: Bankname │ Kontakt: Kontonummer │ Kontakt: Bankleitzahl │ Kontakt: BIC │     Kontakt: IBAN      │          Kontakt: Zusatz 1           │ Kontakt: Zusatz 2 │                                                                                                                Kontakt: Notiz                                                                                                                │ Kontakt: Gruppe │ Kontakt: Zusätzliche Gruppen │ Kontakt: Titel-Lieferanschrift │ Kontakt: Anrede-Lieferanschrift │ Kontakt: Persönlich/Vertraulich-Lieferanschrift │ Kontakt: Vorname-Lieferanschrift │ Kontakt: Name-Lieferanschrift │ Kontakt: Zusatz 1-Lieferanschrift │ Kontakt: Zusatz 2-Lieferanschrift │ Kontakt: Firma-Lieferanschrift │ Kontakt: Straße/Hausnummer-Lieferanschrift │ Kontakt: Postleitzahl-Lieferanschrift │ Kontakt: Ort-Lieferanschrift │ Kontakt: Bundesland-Lieferanschrift │ Kontakt: Land-Lieferanschrift │ Kontakt: Land-Lieferanschrift (Code) │ Kontakt: Preisgruppe │ Kontakt: Kontakt seit │ Kontakt: SEPA-Lastschriftverfahren │ Kontakt: Eingangsdatum des Mandates │ Kontakt: Mandatsreferenz │ Kontakt: Skonto (%) │ Kontakt: Skonto (Tage) │ Kontakt: Rabatt (%/Betrag) │ Kontakt: Zahlungsziel (Tage) │ Kontakt: Umsatzsteueroption │ Kontakt: Umsatzsteueroption ID │ Kontakt: Typ │ Kontakt: Ansprechpartner ID │ Kontakt: Dokumentformat beim Versenden │ Kontakt: Referenz des Käufers │ Kontakt: Lieferantennr. beim Kontakt │ Kontakt: Archiviert │
# │        int64        │         int64         │          varchar           │      varchar       │     varchar     │              int64              │    varchar     │     varchar      │    varchar    │        varchar        │                             varchar                             │          varchar           │        varchar        │      varchar      │       varchar       │    varchar    │       varchar        │      varchar      │             int64              │        varchar        │           varchar            │        varchar         │            varchar            │      varchar       │      varchar       │   varchar    │        varchar        │                 varchar                  │                  varchar                  │      varchar      │                             varchar                             │     varchar     │       varchar       │           varchar            │         varchar          │         varchar         │        varchar        │      varchar      │       varchar        │        varchar        │   varchar    │        varchar         │               varchar                │      varchar      │                                                                                                                   varchar                                                                                                                    │     varchar     │           varchar            │            varchar             │             varchar             │                      int64                      │             varchar              │            varchar            │              varchar              │              varchar              │            varchar             │                  varchar                   │                 int64                 │           varchar            │               varchar               │            varchar            │               varchar                │       varchar        │        varchar        │              varchar               │               varchar               │         varchar          │       varchar       │         int64          │          varchar           │            int64             │           varchar           │            varchar             │   varchar    │           varchar           │                varchar                 │            varchar            │               varchar                │        int64        │
# ├─────────────────────┼───────────────────────┼────────────────────────────┼────────────────────┼─────────────────┼─────────────────────────────────┼────────────────┼──────────────────┼───────────────┼───────────────────────┼─────────────────────────────────────────────────────────────────┼────────────────────────────┼───────────────────────┼───────────────────┼─────────────────────┼───────────────┼──────────────────────┼───────────────────┼────────────────────────────────┼───────────────────────┼──────────────────────────────┼────────────────────────┼───────────────────────────────┼────────────────────┼────────────────────┼──────────────┼───────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────┼─────────────────────────────────────────────────────────────────┼─────────────────┼─────────────────────┼──────────────────────────────┼──────────────────────────┼─────────────────────────┼───────────────────────┼───────────────────┼──────────────────────┼───────────────────────┼──────────────┼────────────────────────┼──────────────────────────────────────┼───────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────┼──────────────────────────────┼────────────────────────────────┼─────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────┼───────────────────────────────┼───────────────────────────────────┼───────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────┼───────────────────────────────────────┼──────────────────────────────┼─────────────────────────────────────┼───────────────────────────────┼──────────────────────────────────────┼──────────────────────┼───────────────────────┼────────────────────────────────────┼─────────────────────────────────────┼──────────────────────────┼─────────────────────┼────────────────────────┼────────────────────────────┼──────────────────────────────┼─────────────────────────────┼────────────────────────────────┼──────────────┼─────────────────────────────┼────────────────────────────────────────┼───────────────────────────────┼──────────────────────────────────────┼─────────────────────┤
# │           804018934 │             100020000 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ ABZ Ambulantes Betreuungs Zentrum GmbH                          │ Werbellinstraße 42         │ 12053                 │ Berlin            │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ m.grundmann@umalleskuemmerkaefer.de      │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ BELADEBEXXX  │ DE39100500000190492899 │ NULL                                 │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 100020000                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          1467417483 │             130000200 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ "Auf der Tenne" e.V.                                            │ Pankelower Weg 13a         │ 18196                 │ Dummerstorf       │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ rechnung@aufdertenne.de                  │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NOLADE21ROS  │ DE47130500000215001559 │ NULL                                 │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130000200                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          1336576739 │             130000069 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ Kassenärztliche Vereinigung Nordrhein                           │ Tersteegenstraße 9         │ 40474                 │ Düsseldorf        │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ rechnungswesen@kvno.de                   │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ DAAEDEDDXXX  │ DE32300606010001417916 │ Körperschaft des öffentlichen Rechts │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130000069                │ NULL                │                      7 │ NULL                       │                           30 │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          1989151063 │             130000808 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ Medios AG                                                       │ Heidestr. 9                │ 10557                 │ Berlin            │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ invoice@medios.ag                        │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ NULL                                 │ NULL              │ Auftragsnummer; ESD-666 angeben                                                                                                                                                                                                              │ NULL            │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130000808                │ NULL                │                      7 │ NULL                       │                           30 │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ default                                │ NULL                          │ NULL                                 │                   0 │
# │          1230152318 │             103000033 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ Caritasverband für den Rheinisch-Bergischen Kreis e.V.          │ Laurentiusstr. 4-12        │ 51465                 │ Bergisch Gladbach │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ rechnungseingang@caritas-rheinberg.de    │ NULL                                      │ NULL              │ Betriebsspezifische Leistungen nach neuer Preisliste abrechnen! │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ COKSDE33XXX  │ DE67370502990311014769 │ NULL                                 │ NULL              │ Preise Vorsorgen: https://crm.zoho.eu/crm/org20078302933/tab/Potentials/386758000018772399\r\nRG muss Name Besteller + 4-stellige KST-Nr. enthalten (Bsp: Müller KST1234)\r\n\r\nAfpa anlassbezogen; AM 100 / AS 50 EUR je h; Stand: 04/2023 │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 103000033                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          2026990494 │             130000890 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ Fischer Connectors GmbH                                         │ Georg-Wimmer-Ring 10       │ 85604                 │ Zorneding         │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ n.elnagari@fischerconnectors.de          │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ NULL                                 │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130000890                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          2027005605 │             130000895 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ IT & I Internet-Technologien und Informationsverarbeitungs-GmbH │ Chausseestr. 111           │ 10115                 │ Berlin            │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ iti-office@iti-software.de               │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ NULL                                 │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130000895                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          2030381955 │             130000915 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ CORVIS GmbH                                                     │ Max-Keith-Straße 66        │ 45136                 │ Essen             │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ rechnung-corvis@corvis.org               │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ NULL                                 │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130000915                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          2035433412 │             130000919 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ Gastro-Event GmbH                                               │ Apostelnstraße 11          │ 50667                 │ Köln              │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ rechnungen@gloria-theater.com            │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ GLORIA                               │ NULL              │ NULL                                                                                                                                                                                                                                         │ NULL            │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130000919                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │           924315506 │             108040031 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ Home24 SE                                                       │ Otto-Ostrowski-Str. 3      │ 10249                 │ Berlin            │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ +49 30 201634703   │ NULL               │ NULL         │ +49 162 2440765       │ buchhaltung@home24.de                    │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ DEUTDEBB101  │ DE19100701000232164400 │ NULL                                 │ NULL              │ KD kann in Zukunft nur 1 Dokument per Mail verarbeiten. Evtl. Anhänge müssen zusammengefasst werden.                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 108040031                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │               ·     │                 ·     │  ·                         │  ·                 │  ·              │                               · │  ·             │  ·               │  ·            │  ·                    │     ·                                                           │           ·                │   ·                   │   ·               │  ·                  │      ·        │ ·                    │  ·                │                             ·  │  ·                    │  ·                           │  ·                     │  ·                            │  ·                 │  ·                 │  ·           │  ·                    │           ·                              │  ·                                        │  ·                │  ·                                                              │  ·              │  ·                  │  ·                           │  ·                       │  ·                      │  ·                    │  ·                │  ·                   │  ·                    │  ·           │  ·                     │  ·                                   │  ·                │  ·                                                                                                                                                                                                                                           │       ·         │  ·                           │  ·                             │  ·                              │                                               · │  ·                               │  ·                            │  ·                                │  ·                                │  ·                             │  ·                                         │                                    ·  │  ·                           │  ·                                  │      ·                        │  ·                                   │  ·                   │ ·                     │  ·                                 │ ·                                   │     ·                    │  ·                  │                      · │  ·                         │                           ·  │           ·                 │  ·                             │   ·          │  ·                          │     ·                                  │  ·                            │  ·                                   │                   · │
# │               ·     │                 ·     │  ·                         │  ·                 │  ·              │                               · │  ·             │  ·               │  ·            │  ·                    │     ·                                                           │           ·                │   ·                   │   ·               │  ·                  │      ·        │ ·                    │  ·                │                             ·  │  ·                    │  ·                           │  ·                     │  ·                            │  ·                 │  ·                 │  ·           │  ·                    │           ·                              │  ·                                        │  ·                │  ·                                                              │  ·              │  ·                  │  ·                           │  ·                       │  ·                      │  ·                    │  ·                │  ·                   │  ·                    │  ·           │  ·                     │  ·                                   │  ·                │  ·                                                                                                                                                                                                                                           │       ·         │  ·                           │  ·                             │  ·                              │                                               · │  ·                               │  ·                            │  ·                                │  ·                                │  ·                             │  ·                                         │                                    ·  │  ·                           │  ·                                  │      ·                        │  ·                                   │  ·                   │ ·                     │  ·                                 │ ·                                   │     ·                    │  ·                  │                      · │  ·                         │                           ·  │           ·                 │  ·                             │   ·          │  ·                          │     ·                                  │  ·                            │  ·                                   │                   · │
# │               ·     │                 ·     │  ·                         │  ·                 │  ·              │                               · │  ·             │  ·               │  ·            │  ·                    │     ·                                                           │           ·                │   ·                   │   ·               │  ·                  │      ·        │ ·                    │  ·                │                             ·  │  ·                    │  ·                           │  ·                     │  ·                            │  ·                 │  ·                 │  ·           │  ·                    │           ·                              │  ·                                        │  ·                │  ·                                                              │  ·              │  ·                  │  ·                           │  ·                       │  ·                      │  ·                    │  ·                │  ·                   │  ·                    │  ·           │  ·                     │  ·                                   │  ·                │  ·                                                                                                                                                                                                                                           │       ·         │  ·                           │  ·                             │  ·                              │                                               · │  ·                               │  ·                            │  ·                                │  ·                                │  ·                             │  ·                                         │                                    ·  │  ·                           │  ·                                  │      ·                        │  ·                                   │  ·                   │ ·                     │  ·                                 │ ·                                   │     ·                    │  ·                  │                      · │  ·                         │                           ·  │           ·                 │  ·                             │   ·          │  ·                          │     ·                                  │  ·                            │  ·                                   │                   · │
# │          2356538478 │             130001883 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ Hauskrankenpflege Zeuthen GmbH                                  │ Miersdorfer Chaussee 14    │ 15738                 │ Zeuthen           │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ personal@hauskrankenpflege-zeuthen.de    │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ NULL                                 │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130001883                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          2356533804 │             130001882 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ FITS job konzepte GmbH                                          │ Bürgerweide 4              │ 20535                 │ Hamburg           │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ info@fits.de                             │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ NULL                                 │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130001882                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# ...
# │          2521040392 │             130002294 │ NULL                       │ NULL               │ Herrn           │                               0 │ NULL           │ Hamid            │ Bachiri       │ NULL                  │ NULL                                                            │ In der Schildwacht 13      │ 65933                 │ Frankfurt         │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ abrechnung@mesiodent.de                  │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ Zahntechnik, MesioDent               │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130002294                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          2521158112 │             130002296 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ VITAGO Personal GmbH                                            │ Am Carlsgarten 10 B        │ 10318                 │ Berlin            │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ grabow@vitago-personal.de                │ NULL                                      │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ NULL                                 │ NULL              │ Neukundenrabat von 5% auf die Vorsorgen im erste Betreuungsjahr 2026                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130002296                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# │          2521212412 │             130002305 │ NULL                       │ NULL               │ NULL            │                               0 │ NULL           │ NULL             │ NULL          │ NULL                  │ Martha-Maria Altenhilfe gGmbH                                   │ Stadenstraße 60            │ 90491                 │ Nürnberg          │ NULL                │ Deutschland   │ DE                   │ NULL              │                           NULL │ NULL                  │ NULL                         │ NULL                   │ NULL                          │ NULL               │ NULL               │ NULL         │ NULL                  │ eingangsrechnungen@martha-maria.de       │ seniorenzentrum.stuttgart@martha-maria.de │ NULL              │ NULL                                                            │ NULL            │ NULL                │ NULL                         │ NULL                     │ NULL                    │ NULL                  │ NULL              │ NULL                 │ NULL                  │ NULL         │ NULL                   │ c/o Diakoniewerk Martha-Maria e.V.   │ NULL              │ NULL                                                                                                                                                                                                                                         │ Grundbetreuung  │ NULL                         │ NULL                           │ NULL                            │                                               0 │ NULL                             │ NULL                          │ NULL                              │ NULL                              │ NULL                           │ NULL                                       │                                  NULL │ NULL                         │ NULL                                │ Deutschland                   │ NULL                                 │ NULL                 │ #                     │ NULL                               │ #                                   │ 130002305                │ NULL                │                      7 │ NULL                       │                         NULL │ Umsatzsteuerpflichtig       │ NULL                           │ Kunde        │ NULL                        │ zugferd2_2                             │ NULL                          │ NULL                                 │                   0 │
# ├─────────────────────┴───────────────────────┴────────────────────────────┴────────────────────┴─────────────────┴─────────────────────────────────┴────────────────┴──────────────────┴───────────────┴───────────────────────┴─────────────────────────────────────────────────────────────────┴────────────────────────────┴───────────────────────┴───────────────────┴─────────────────────┴───────────────┴──────────────────────┴───────────────────┴────────────────────────────────┴───────────────────────┴──────────────────────────────┴────────────────────────┴───────────────────────────────┴────────────────────┴────────────────────┴──────────────┴───────────────────────┴──────────────────────────────────────────┴───────────────────────────────────────────┴───────────────────┴─────────────────────────────────────────────────────────────────┴─────────────────┴─────────────────────┴──────────────────────────────┴──────────────────────────┴─────────────────────────┴───────────────────────┴───────────────────┴──────────────────────┴───────────────────────┴──────────────┴────────────────────────┴──────────────────────────────────────┴───────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────────┴──────────────────────────────┴────────────────────────────────┴─────────────────────────────────┴─────────────────────────────────────────────────┴──────────────────────────────────┴───────────────────────────────┴───────────────────────────────────┴───────────────────────────────────┴────────────────────────────────┴────────────────────────────────────────────┴───────────────────────────────────────┴──────────────────────────────┴─────────────────────────────────────┴───────────────────────────────┴──────────────────────────────────────┴──────────────────────┴───────────────────────┴────────────────────────────────────┴─────────────────────────────────────┴──────────────────────────┴─────────────────────┴────────────────────────┴────────────────────────────┴──────────────────────────────┴─────────────────────────────┴────────────────────────────────┴──────────────┴─────────────────────────────┴────────────────────────────────────────┴───────────────────────────────┴──────────────────────────────────────┴─────────────────────┤
# │ 797 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         78 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## eb / zoho name matched

# %%
duck.sql(
    """
    with clean_zoho as (
        select 
            * replace(
                trim(unnest(split(Account_Name, '/'))) as Account_Name
            ),
            clean_account_name(trim(unnest(split(Account_Name, '/')))) as clean_name
        from pg.zoho.Accounts
    ), clean_easybill as (
        select 
            * replace(
                trim(unnest(split("Kontakt: Firma", '/'))) as "Kontakt: Firma"
            ),
            clean_account_name(trim(unnest(split("Kontakt: Firma", '/')))) as clean_name
        from read_csv('/Users/adrienblanquer/Downloads/easybill_contacts_inv_rec_activ.csv')
    )
    select 
        z.Id as zoho_id,
        easybill."Kontakt: Kundennummer" as easybill_customer_number,
        easybill."Kontakt: Firma" as easybill_name,
        easybill.clean_name as clean_easybill_name,
        z.Account_Name as zoho_name,
        z.clean_name as clean_zoho_name,
        jaro_winkler_similarity(clean_account_name(easybill."Kontakt: Firma"), z.clean_name) as sim

    from clean_easybill as easybill

    join (select * from clean_zoho where Account_Name <> '' and length(Account_Name) > 1 and length(clean_name) > 3 and clean_name <> 'test') z
        on jaro_winkler_similarity(clean_account_name(easybill."Kontakt: Firma"), z.clean_name) > 0.95
        or (easybill.clean_name in z.clean_name or z.clean_name in easybill.clean_name and jaro_winkler_similarity(clean_account_name(easybill."Kontakt: Firma"), z.clean_name) > 0.6)
    QUALIFY row_number() OVER (PARTITION BY easybill."Kontakt: Kundennummer" ORDER BY sim DESC) = 1
    """
).to_csv('output/easybill_zoho_name_matched.csv')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# ## not matching rows

# %% [markdown]
# # address and name matching

# %% [markdown]
# ## eb/zoho matched rows

# %%
duck.sql(
    """
    with zoho_raw_add as (
        select 
            Id, 
            Account_Name, 
            Billing_Street || ' ' || Billing_Code || ', Deutshcland' as full_billing_address, 
            Shipping_Street || ' ' || Shipping_Code || ', Deutshcland' as full_shipping_address
        from pg.zoho.Accounts 
        offset 1
    ), zoho_dist_add as (
        select
            Id,
            Account_Name,
            list_distinct([full_billing_address, full_shipping_address]) as address
        from zoho_raw_add
        group by all
        order by Id
    ), zoho_all_raw_add as (
        select
            z.Id,
            z.Account_Name,
            t.raw_address,
        from zoho_dist_add z
        left join lateral unnest(z.address) as t(raw_address) on true
    ), zoho_all_parsed_add as (
        select
            z.*,
            parsed_address->'house_number' as house_number,
            parsed_address->'road' as road,
            udf_clean_german_road(parsed_address->'road') as clean_road,
            parsed_address->'postcode' as postcode,
            parsed_address->'country' as country,
        from (select Id, Account_Name as zoho_name, udf_parse_address(raw_address)::json as parsed_address from zoho_all_raw_add) as z
    ), easybill_raw_add as (
        select distinct on("Kontakt: Kundennummer")
            "Kontakt: Kundennummer" as eb_id,
            "Kontakt: Firma" as eb_name,
            "Kontakt: Straße/Hausnummer" as eb_nb_street,
            "Kontakt: Postleitzahl" as eb_postcode,
            *
        from read_csv('/Users/adrienblanquer/Downloads/easybill_contacts_inv_rec_activ.csv')
    ), easybill_all_parsed_add as (
        select
            eb_id,
            eb_name,
            parsed_address->'house_number' as house_number,
            parsed_address->'road' as road,
            udf_clean_german_road(parsed_address->'road') as clean_road,
            parsed_address->'postcode' as postcode,
            parsed_address->'country' as country,
        from (select *, udf_parse_address(eb_nb_street || ' ' || eb_postcode || ', Deutschland')::json as parsed_address from easybill_raw_add) as e
    )
    select *,
        jaro_winkler_similarity(clean_account_name(zoho_name), clean_account_name(eb_name)) as name_sim,
    from easybill_all_parsed_add
    join zoho_all_parsed_add
        on (jaro_winkler_similarity(easybill_all_parsed_add.clean_road, zoho_all_parsed_add.clean_road) > 0.95
        and easybill_all_parsed_add.postcode = zoho_all_parsed_add.postcode
        and jaro_winkler_similarity(easybill_all_parsed_add.house_number, zoho_all_parsed_add.house_number) > 0.95)       
    --where Id = '386758000035779091'
    --where Id IS NULL
    qualify row_number() over (partition by eb_id order by name_sim desc) = 1
    order by eb_id
    """).to_csv('output/easybill_zoho_address_and_name_matched.csv')

# %% [markdown]
# ## eb/zoho unmatched rows

# %%
duck.sql(
    """
    with zoho_raw_add as (
        select 
            Id, 
            Account_Name, 
            Billing_Street || ' ' || Billing_Code || ', Deutshcland' as full_billing_address, 
            Shipping_Street || ' ' || Shipping_Code || ', Deutshcland' as full_shipping_address
        from pg.zoho.Accounts 
        offset 1
    ), zoho_dist_add as (
        select
            Id,
            Account_Name,
            list_distinct([full_billing_address, full_shipping_address]) as address
        from zoho_raw_add
        group by all
        order by Id
    ), zoho_all_raw_add as (
        select
            z.Id,
            z.Account_Name,
            t.raw_address,
        from zoho_dist_add z
        left join lateral unnest(z.address) as t(raw_address) on true
    ), zoho_all_parsed_add as (
        select
            z.*,
            parsed_address->'house_number' as house_number,
            parsed_address->'road' as road,
            udf_clean_german_road(parsed_address->'road') as clean_road,
            parsed_address->'postcode' as postcode,
            parsed_address->'country' as country,
        from (select Id, Account_Name as zoho_name, udf_parse_address(raw_address)::json as parsed_address from zoho_all_raw_add) as z
    ), easybill_raw_add as (
        select distinct on("Kontakt: Kundennummer")
            "Kontakt: Kundennummer" as eb_id,
            "Kontakt: Firma" as eb_name,
            "Kontakt: Straße/Hausnummer" as eb_nb_street,
            "Kontakt: Postleitzahl" as eb_postcode,
            *
        from read_csv('/Users/adrienblanquer/Downloads/easybill_contacts_inv_rec_activ.csv')
    ), easybill_all_parsed_add as (
        select
            eb_id,
            eb_name,
            parsed_address->'house_number' as house_number,
            parsed_address->'road' as road,
            udf_clean_german_road(parsed_address->'road') as clean_road,
            parsed_address->'postcode' as postcode,
            parsed_address->'country' as country,
        from (select *, udf_parse_address(eb_nb_street || ' ' || eb_postcode || ', Deutschland')::json as parsed_address from easybill_raw_add) as e
    )
    select *,
        jaro_winkler_similarity(clean_account_name(zoho_name), clean_account_name(eb_name)) as name_sim,
    from easybill_all_parsed_add
    left join zoho_all_parsed_add
        on (jaro_winkler_similarity(easybill_all_parsed_add.clean_road, zoho_all_parsed_add.clean_road) > 0.95
        and easybill_all_parsed_add.postcode = zoho_all_parsed_add.postcode
        and jaro_winkler_similarity(easybill_all_parsed_add.house_number, zoho_all_parsed_add.house_number) > 0.95)       
    --where Id = '386758000035779091'
    where Id IS NULL
    qualify row_number() over (partition by eb_id order by name_sim desc) = 1
    order by eb_id
    """)
#.to_csv('output/easybill_zoho_address_and_name_matched.csv')
# Out:
# ┌───────────┬─────────────────────────────────────────────────────────────────────────────────────┬──────────────┬─────────────────────────────────┬─────────────────────────────┬──────────┬───────────────┬─────────┬───────────┬────────────────┬──────────────┬──────┬────────────┬──────────┬─────────┬──────────┐
# │   eb_id   │                                       eb_name                                       │ house_number │              road               │         clean_road          │ postcode │    country    │   Id    │ zoho_name │ parsed_address │ house_number │ road │ clean_road │ postcode │ country │ name_sim │
# │   int64   │                                       varchar                                       │     json     │              json               │           varchar           │   json   │     json      │ varchar │  varchar  │      json      │     json     │ json │  varchar   │   json   │  json   │  double  │
# ├───────────┼─────────────────────────────────────────────────────────────────────────────────────┼──────────────┼─────────────────────────────────┼─────────────────────────────┼──────────┼───────────────┼─────────┼───────────┼────────────────┼──────────────┼──────┼────────────┼──────────┼─────────┼──────────┤
# │ 101000049 │ BG-Pflege GmbH                                                                      │ "16"         │ "zehntweg"                      │ zehntweg                    │ "51467"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 102000001 │ CURAVERDE Pflegedienst GmbH                                                         │ NULL         │ NULL                            │ NULL                        │ "16515"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 103000022 │ convit GmbH                                                                         │ "39"         │ "d7"                            │ d7                          │ "51063"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 104000004 │ D4L data4life gGmbH                                                                 │ "187"        │ "rudolf-breitscheid-straße"     │ rudolfbreitscheid           │ "14482"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 104000011 │ D & K Aufzgsdienst GbR                                                              │ "2"          │ "wölfelsgasse"                  │ wolfelsgasse                │ "68535"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 104000051 │ Fraunhofer IGD Rostock                                                              │ "11"         │ "joachim-jungius-str."          │ joachimjungius              │ "18059"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 105010069 │ xpress seals gmbh                                                                   │ "70-74"      │ "fangdieckstr."                 │ fangdieck                   │ "22547"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 105010071 │ Echtzeit GmbH & Co. KG                                                              │ "4"          │ "humboldtstraße"                │ humboldt                    │ "40237"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 106020007 │ Dept Marketing GmbH                                                                 │ "53/54"      │ "hagelberger straße"            │ hagelberger                 │ "10965"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 106020036 │ effekt - Soziale Hilfen GmbH & Co. KG                                               │ "350"        │ "altonaer str."                 │ altonaer                    │ "25469"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │     ·     │                   ·                                                                 │   ·          │     ·                           │  ·                          │    ·     │       ·       │  ·      │  ·        │  ·             │  ·           │  ·   │  ·         │  ·       │  ·      │       ·  │
# │     ·     │                   ·                                                                 │   ·          │     ·                           │  ·                          │    ·     │       ·       │  ·      │  ·        │  ·             │  ·           │  ·   │  ·         │  ·       │  ·      │       ·  │
# │     ·     │                   ·                                                                 │   ·          │     ·                           │  ·                          │    ·     │       ·       │  ·      │  ·        │  ·             │  ·           │  ·   │  ·         │  ·       │  ·      │       ·  │
# │ 130002317 │ Gesellschaft für Service und Dienstleistungen im Gesundheitswesen mbH - Plau am See │ "5-7"        │ "badstr."                       │ bad                         │ "19336"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 130002318 │ C&C Service GmbH - Güstrow                                                          │ "5-7"        │ "badstr."                       │ bad                         │ "19336"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 130002319 │ C&C R Nord GmbH - Plau am See                                                       │ "5-7"        │ "badstr."                       │ bad                         │ "19336"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 130002320 │ KMG Seniorenheime GmbH                                                              │ "1b"         │ "friedrich-trendelenburg-allee" │ friedrichtrendelenburgallee │ "18273"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 130002321 │ KMG Klinik Silbermühle GmbH                                                         │ "24"         │ "millionenweg"                  │ millionenweg                │ "19395"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 130002323 │ KMG Klinikum Mitte Service GmbH                                                     │ "5-7"        │ "badstr."                       │ bad                         │ "19336"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 130002324 │ C&C Service GmbH - Plau am See                                                      │ "5-7"        │ "badstr."                       │ bad                         │ "19336"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 130002325 │ C&C R Nord GmbH - Güstrow                                                           │ "5-7"        │ "badstr."                       │ bad                         │ "19336"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 130002326 │ Gesellschaft für Service und Dienstleistungen im Gesundheitswesen mbH - Güstrow     │ "5-7"        │ "badstr."                       │ bad                         │ "19336"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# │ 600310000 │ Kinderheldin GmbH                                                                   │ "25"         │ "max-beer-str."                 │ maxbeer                     │ "10119"  │ "deutschland" │ NULL    │ NULL      │ NULL           │ NULL         │ NULL │ NULL       │ NULL     │ NULL    │     NULL │
# ├───────────┴─────────────────────────────────────────────────────────────────────────────────────┴──────────────┴─────────────────────────────────┴─────────────────────────────┴──────────┴───────────────┴─────────┴───────────┴────────────────┴──────────────┴──────┴────────────┴──────────┴─────────┴──────────┤
# │ 87 rows (20 shown)                                                                                                                                                                                                                                                                                       16 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # merge both matchings

# %%
duck.sql(
    """
with name_addr_matches as (
    select 
        'addr_name_'||row_number() over (order by eb_id) as row_num,
        eb_id as easybill_id,
        eb_name as easybill_name,
        Id as zoho_id,
        zoho_name,
        name_sim as sim
    from read_csv('output/easybill_zoho_address_and_name_matched.csv')
    ), name_only_matches as (
        select 
        'name_'||row_number() over (order by easybill_customer_number) as row_num,
        easybill_customer_number as easybill_id,
        easybill_name,
        zoho_id,
        zoho_name,
        sim
        
    from read_csv('output/easybill_zoho_name_matched.csv')
    ), all_matches as (
        select * from name_addr_matches
        union all
        select * from name_only_matches
    )
    select *
    from all_matches
    qualify row_number() over (partition by easybill_id order by sim desc) = 1
    """
).to_csv('output/easybill_zoho_final_matches.csv')

# %% [markdown]
# ## still no matching

# %%
duck.sql(
    """
    select 
        distinct on ("Kontakt: Kundennummer") *  
    from read_csv('/Users/adrienblanquer/Downloads/easybill_contacts_inv_rec_activ.csv') 
    where "Kontakt: Kundennummer" not in (
        select easybill_id from read_csv('output/easybill_zoho_final_matches.csv')
        )
    """
).to_csv('output/easybill_zoho_final_unmatched.csv')

# %%
duck.sql("select distinct \"Kontakt: Kundennummer\" from read_csv('/Users/adrienblanquer/Downloads/easybill_contacts_inv_rec_activ.csv')")
# Out:
# ┌───────────────────────┐
# │ Kontakt: Kundennummer │
# │         int64         │
# ├───────────────────────┤
# │             130000425 │
# │             130000185 │
# │             105010055 │
# │             130000858 │
# │             130000877 │
# │             130000882 │
# │             130000886 │
# │             130000888 │
# │             130000920 │
# │             130000925 │
# │                 ·     │
# │                 ·     │
# │                 ·     │
# │             130001824 │
# │             130001844 │
# │             130001845 │
# │             130001892 │
# │             130002045 │
# │             130002102 │
# │             130002105 │
# │             130002141 │
# │             130002176 │
# │             130002320 │
# ├───────────────────────┤
# │  797 rows (20 shown)  │
# └───────────────────────┘

# %%
duck.sql("""
        select easybill_id from read_csv('output/easybill_zoho_final_matches.csv')

         """)
# Out:
# ┌─────────────┐
# │ easybill_id │
# │    int64    │
# ├─────────────┤
# │   101000015 │
# │   102000005 │
# │   102000006 │
# │   108040029 │
# │   108040050 │
# │   110010000 │
# │   111000023 │
# │   111000050 │
# │   111001011 │
# │   113000000 │
# │       ·     │
# │       ·     │
# │       ·     │
# │   130001760 │
# │   130001819 │
# │   130001971 │
# │   130001978 │
# │   130002145 │
# │   130002306 │
# │   130002307 │
# │   130002314 │
# │   130002329 │
# │   130002333 │
# ├─────────────┤
# │  777 rows   │
# │ (20 shown)  │
# └─────────────┘
